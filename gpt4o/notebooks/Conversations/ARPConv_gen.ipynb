# %% [markdown]
# # Creación de conversaciones ARP

# %% [markdown]
# ### Descripción:
# Con este código se va a intentar crear todos los pasos de una conversación ARP, mediante IA generativa. Se pretende pasar una descripción de esta conversación al modelo y que este sea capaz de crear todos los pasos/paquetes necesarios para replicar una conversación con esas mismas especificaciones

# %%
import random
import re
import pickle
import math
import time
import os 

import openai
from openai import OpenAI
os.environ['OPENAI_API_KEY'] = 'Fill'
client = OpenAI()

from scapy.all import *
from scapy.utils import RawPcapReader, wrpcap
import scapy.all as scapy

from scapy.layers.l2 import Ether, ARP

openai.__version__
# Out:
# C:\Users\adayd\anaconda3\envs\PAC-GPT\Lib\site-packages\scapy\layers\ipsec.py:469: CryptographyDeprecationWarning: Blowfish has been deprecated
#   cipher=algorithms.Blowfish,
# C:\Users\adayd\anaconda3\envs\PAC-GPT\Lib\site-packages\scapy\layers\ipsec.py:483: CryptographyDeprecationWarning: CAST5 has been deprecated
#   cipher=algorithms.CAST5,
# '1.10.0'

# %% [markdown]
# ## Generación de la descipción de una comunicación ARP

# %% [markdown]
# <center><img src="https://lh3.googleusercontent.com/proxy/5BFPjEuLzirf_rQUpK9oPibFDhfXjP7eez9zJdPXfEl5QZyEp6jLTDSpVc8RBygmwlQ5s4hV-V_muXLdOGmmrsjD-JaqO4HtlQHkO1D8Tj8">
#
# <center> Esta imagen es genérica, nosotros crearemos conversaciones que sean tanto una pregunta a broadcast como a una ubicación específica.
# <br>
#     ---
# <br>Una conversación normal ARP tiene una petición (opcode = 1) en la que una fuente pregunta a broadcast o a otro elemento de la red por una IP en concreto, y diciendo la IP a la que comunicar la respuesta.
# La respuesta tiene (opcode = 2), y tiene como fuente las respuestas, mientras que como destino tiene al que inicia la conversación.
# <center>---
#
# La primera query (query1) representa una conexión ARP sencilla donde se envía la petición a un equipo específico, la segunda (query2) es más complicada, enviando la solicitud a broadcast.

# %%
system_message1 = "This is a ARP conversation summary:\n"
system_message1 += 'Source: MAC="c2:3d:19:6c:00:01", IP="10.0.0.1" // Destination: MAC="c2:3c:19:6c:00:01" // Wanted: IP= "10.0.0.2"\n'
system_message1 += "This is the python code to generate the request and reply packets of the conversation, respectively:\n"
system_message1 += 'pkt_1=scapy.Ether(src="c2:3d:19:6c:00:01", dst="c2:3c:19:6c:00:01")/scapy.ARP(op=1, pdst="10.0.0.2", psrc="10.0.0.1", hwdst="c2:3c:19:6c:00:01", hwsrc="c2:3d:19:6c:00:01")\n'
system_message1 += 'time.sleep(abs(random.gauss(0, 0.03)))'
system_message1 += 'pkt_2=scapy.Ether(src="c2:3c:19:6c:00:01", dst="c2:3d:19:6c:00:01")/scapy.ARP(op=2, psrc="10.0.0.2", hwsrc="c2:3c:19:6c:00:01", hwdst="c2:3d:19:6c:00:01",  pdst="10.0.0.1")\n'

# %%
system_message2 = "This is a ARP conversation summary:\n"
system_message2 += 'Source: MAC="c2:3d:19:6c:00:01", IP="10.0.0.1" // Destination: MAC="FF:FF:FF:FF:FF:FF" // Wanted: IP= "10.0.0.2"\n'
system_message2 += "This is the python code to generate the request and reply packets of the conversation, respectively:\n"
system_message2 += 'pkt_1=scapy.Ether(src="c2:3d:19:6c:00:01", dst="FF:FF:FF:FF:FF:FF")/scapy.ARP(op=1, pdst="10.0.0.2", psrc="10.0.0.1", hwdst="00:00:00:00:00:00", hwsrc="c2:3d:19:6c:00:01")\n'
system_message2 += 'time.sleep(abs(random.gauss(0, 0.03)))'
system_message2 += 'rand_MAC= "02:00:00:%02x:%02x:%02x" % (random.randint(0, 255),random.randint(0, 255),random.randint(0, 255))'
system_message2 += 'pkt_2=scapy.Ether(src=rand_MAC, dst="c2:3d:19:6c:00:01")/scapy.ARP(op=2, psrc="10.0.0.2", hwsrc=rand_MAC, hwdst="c2:3d:19:6c:00:01",  pdst="10.0.0.1")\n'
system_message2 += 'Take your time (few seconds) to think if the packets and their variables make sense for an ARP converstaion, if not, correct them\n'

# %% [markdown]
# ## Carga de posibles conversaciones

# %%
with open("../../data/Conversations/ARP/Conv_summaries.txt","r",encoding="utf8") as f:
    Conv_summaries = f.read().splitlines()

print("Número de resúmenes: " +str(len(Conv_summaries)))
# Out:
# Número de resúmenes: 75

# %% [markdown]
# ### Carga de posibles respuestas anteriores para encadenarlas

# %%
class response():
    "Stores name and place pairs"
    def __init__(self, name, place):
        self.prompt_summary = name
        self.completion = place

# %%
try:
    responses = pickle.load( open("../../data/Conversations/pickle/ARP_pairs_Aday.pkl", "rb" ))
except:
    responses = []
    
print("Number of previous responses: " + str(len(responses)))
# Out:
# Number of previous responses: 0

# %% [markdown]
# ## Generación de comandos de paquetes de conversación

# %%
for i in range(len(Conv_summaries)):
   
    summary = Conv_summaries[i]
    
    print("...........................................")
    print( " GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter " +str(i+1) +")")
    

    ## Luego seleccionas aleatoriamente resumenes ya generados para pedirle que te saque el comando a partir del paquete
    #summaries = random.choices(Conv_summary,k=summaries_per_request)
    text_sum = ""
    
    if summary.find('FF:FF:FF:FF:FF:FF') == -1: # No esta, es decir, entre disps

        query_content = "This is a conversation summary:\n"
        query_content += summary + "\n"
        text_sum += summary + "\n"
        query_content += "\nGenerate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.\n\n"
        query_content += "Use the following structure:\n"
        query_content += "pkt_1=...\n"
        query_content += "time.sleep(abs(random.gauss(0, 0.03)))\n"
        query_content += "pkt_2=...\n"
        
        #Query es el mensaje que le envias al modelo
        print(query_content)

        messages=[{"role": "system", "content": system_message1},
        {"role": "user", "content": query_content}]
    
        #Esta es la petición que le mandas al modelo de IA
        completion = client.chat.completions.create(
        model="gpt-4o", 
        messages=messages,
        max_tokens=2600,
        temperature=0.1)

    else: #si esta, es decir, broadcast

        query_content += "This is a conversation summary:\n"
        query_content += summary + "\n"
        text_sum += summary + "\n"
        query_content += "\nGenerate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.\n\n"
        query_content += "Use the following structure:\n"
        query_content += "pkt_1=...\n"
        query_content += "time.sleep(random.randint(1,10)/1000000.0)\n"
        query_content += "rand_MAC=...\n"
        query_content += "pkt_2=...\n"
        #Query es el mensaje que le envias al modelo
        print(query_content)

        messages=[{"role": "system", "content": system_message2},
        {"role": "user", "content": query_content}]
    
        #Esta es la petición que le mandas al modelo de IA
        completion = client.chat.completions.create(
        model="gpt-4o", 
        messages=messages,
        max_tokens=2600,
        temperature=0.1)

    
    print("...Generated!")
    
    # Guardamos tanto el resumen de los paquetes que solicitamos y lo que devuelve el modelo para estos paquetes
    responses.append(response(text_sum, completion))
    
    # Guardamos tanto la petición como la respuesta en un archivo
    pickle.dump(responses, open( "../../data/Conversations/ARP/pickle/ARP_pairs_Aday.pkl", "wb" ) )
    
    exec(responses[-1].completion.choices[0].message.content)
    # Guardamos los paquetes generados en un pcap
    with open("../../data/Conversations/ARP/pcap/ARP_generated_gpt_4o.pcap", "ba+") as f:
        wrpcap(f, pkt_1, append=True)
    
    with open("../../data/Conversations/ARP/pcap/ARP_generated_gpt_4o.pcap", "ba+") as f:
        wrpcap(f, pkt_2, append=True)
    
    print("Number of completitions done: " + str(len(responses)))
# Out:
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 1)
# This is a conversation summary:
# Source: MAC=“e9:f0:a1:b2:c3:d4”, IP=“10.10.20.1” // Destination: MAC=“d4:c3:b2:a1:f0:e9” // Wanted: IP= “10.10.20.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 1
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 2)
# This is a conversation summary:
# Source: MAC=“e9:f0:a1:b2:c3:d4”, IP=“10.10.20.1” // Destination: MAC=“d4:c3:b2:a1:f0:e9” // Wanted: IP= “10.10.20.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“f1:a2:b3:c4:d5:e6”, IP=“172.16.1.10” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “172.16.1.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 2
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 3)
# This is a conversation summary:
# Source: MAC=“a3:b4:c5:d6:e7:f8”, IP=“192.168.3.10” // Destination: MAC=“f8:e7:d6:c5:b4:a3” // Wanted: IP= “192.168.3.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 3
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 4)
# This is a conversation summary:
# Source: MAC=“a3:b4:c5:d6:e7:f8”, IP=“192.168.3.10” // Destination: MAC=“f8:e7:d6:c5:b4:a3” // Wanted: IP= “192.168.3.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“b5:c6:d7:e8:f9:a0”, IP=“10.10.30.1” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “10.10.30.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 4
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 5)
# This is a conversation summary:
# Source: MAC=“c7:d8:e9:f0:a1:b2”, IP=“172.16.2.10” // Destination: MAC=“b2:a1:f0:e9:d8:c7” // Wanted: IP= “172.16.2.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 5
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 6)
# This is a conversation summary:
# Source: MAC=“c7:d8:e9:f0:a1:b2”, IP=“172.16.2.10” // Destination: MAC=“b2:a1:f0:e9:d8:c7” // Wanted: IP= “172.16.2.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“d9:e0:f1:a2:b3:c4”, IP=“192.168.4.10” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “192.168.4.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 6
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 7)
# This is a conversation summary:
# Source: MAC=“e1:f2:a3:b4:c5:d6”, IP=“10.10.40.1” // Destination: MAC=“d6:c5:b4:a3:f2:e1” // Wanted: IP= “10.10.40.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 7
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 8)
# This is a conversation summary:
# Source: MAC=“e1:f2:a3:b4:c5:d6”, IP=“10.10.40.1” // Destination: MAC=“d6:c5:b4:a3:f2:e1” // Wanted: IP= “10.10.40.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“f3:a4:b5:c6:d7:e8”, IP=“172.16.3.10” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “172.16.3.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 8
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 9)
# This is a conversation summary:
# Source: MAC=“a5:b6:c7:d8:e9:f0”, IP=“192.168.5.10” // Destination: MAC=“f0:e9:d8:c7:b6:a5” // Wanted: IP= “192.168.5.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 9
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 10)
# This is a conversation summary:
# Source: MAC=“a5:b6:c7:d8:e9:f0”, IP=“192.168.5.10” // Destination: MAC=“f0:e9:d8:c7:b6:a5” // Wanted: IP= “192.168.5.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“b7:c8:d9:e0:f1:a2”, IP=“10.10.50.1” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “10.10.50.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 10
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 11)
# This is a conversation summary:
# Source: MAC=“c9:d0:e1:f2:a3:b4”, IP=“172.16.4.10” // Destination: MAC=“b4:a3:f2:e1:d0:c9” // Wanted: IP= “172.16.4.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 11
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 12)
# This is a conversation summary:
# Source: MAC=“c9:d0:e1:f2:a3:b4”, IP=“172.16.4.10” // Destination: MAC=“b4:a3:f2:e1:d0:c9” // Wanted: IP= “172.16.4.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“e0:f1:a2:b3:c4:d5”, IP=“192.168.6.10” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “192.168.6.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 12
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 13)
# This is a conversation summary:
# Source: MAC=“f2:a3:b4:c5:d6:e7”, IP=“10.10.60.1” // Destination: MAC=“e7:d6:c5:b4:a3:f2” // Wanted: IP= “10.10.60.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 13
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 14)
# This is a conversation summary:
# Source: MAC=“f2:a3:b4:c5:d6:e7”, IP=“10.10.60.1” // Destination: MAC=“e7:d6:c5:b4:a3:f2” // Wanted: IP= “10.10.60.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“a4:b5:c6:d7:e8:f9”, IP=“172.16.5.10” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “172.16.5.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 14
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 15)
# This is a conversation summary:
# Source: MAC=“b6:c7:d8:e9:f0:a1”, IP=“192.168.7.10” // Destination: MAC=“a1:f0:e9:d8:c7:b6” // Wanted: IP= “192.168.7.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 15
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 16)
# This is a conversation summary:
# Source: MAC=“b6:c7:d8:e9:f0:a1”, IP=“192.168.7.10” // Destination: MAC=“a1:f0:e9:d8:c7:b6” // Wanted: IP= “192.168.7.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“c8:d9:e0:f1:a2:b3”, IP=“10.10.70.1” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “10.10.70.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 16
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 17)
# This is a conversation summary:
# Source: MAC=“d0:e1:f2:a3:b4:c5”, IP=“172.16.6.10” // Destination: MAC=“c5:b4:a3:f2:e1:d0” // Wanted: IP= “172.16.6.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 17
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 18)
# This is a conversation summary:
# Source: MAC=“d0:e1:f2:a3:b4:c5”, IP=“172.16.6.10” // Destination: MAC=“c5:b4:a3:f2:e1:d0” // Wanted: IP= “172.16.6.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“e2:f3:a4:b5:c6:d7”, IP=“192.168.8.10” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “192.168.8.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 18
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 19)
# This is a conversation summary:
# Source: MAC=“f4:a5:b6:c7:d8:e9”, IP=“10.10.80.1” // Destination: MAC=“e9:d8:c7:b6:a5:f4” // Wanted: IP= “10.10.80.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 19
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 20)
# This is a conversation summary:
# Source: MAC=“f4:a5:b6:c7:d8:e9”, IP=“10.10.80.1” // Destination: MAC=“e9:d8:c7:b6:a5:f4” // Wanted: IP= “10.10.80.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“a6:b7:c8:d9:e0:f1”, IP=“172.16.7.10” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “172.16.7.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 20
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 21)
# This is a conversation summary:
# Source: MAC=“b8:c9:d0:e1:f2:a3”, IP=“192.168.9.10” // Destination: MAC=“a3:f2:e1:d0:c9:b8” // Wanted: IP= “192.168.9.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 21
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 22)
# This is a conversation summary:
# Source: MAC=“b8:c9:d0:e1:f2:a3”, IP=“192.168.9.10” // Destination: MAC=“a3:f2:e1:d0:c9:b8” // Wanted: IP= “192.168.9.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“c0:d1:e2:f3:a4:b5”, IP=“10.10.90.1” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “10.10.90.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 22
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 23)
# This is a conversation summary:
# Source: MAC=“d2:e3:f4:a5:b6:c7”, IP=“172.16.8.10” // Destination: MAC=“c7:b6:a5:f4:e3:d2” // Wanted: IP= “172.16.8.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 23
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 24)
# This is a conversation summary:
# Source: MAC=“d2:e3:f4:a5:b6:c7”, IP=“172.16.8.10” // Destination: MAC=“c7:b6:a5:f4:e3:d2” // Wanted: IP= “172.16.8.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“e4:f5:a6:b7:c8:d9”, IP=“192.168.10.10” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “192.168.10.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 24
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 25)
# This is a conversation summary:
# Source: MAC=“f6:a7:b8:c9:d0:e1”, IP=“10.10.100.1” // Destination: MAC=“e1:d0:c9:b8:a7:f6” // Wanted: IP= “10.10.100.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 25
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 26)
# This is a conversation summary:
# Source: MAC=“f6:a7:b8:c9:d0:e1”, IP=“10.10.100.1” // Destination: MAC=“e1:d0:c9:b8:a7:f6” // Wanted: IP= “10.10.100.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“a8:b9:c0:d1:e2:f3”, IP=“172.16.9.10” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “172.16.9.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 26
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 27)
# This is a conversation summary:
# Source: MAC=“b0:c1:d2:e3:f4:a5”, IP=“192.168.11.10” // Destination: MAC=“a5:f4:e3:d2:c1:b0” // Wanted: IP= “192.168.11.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 27
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 28)
# This is a conversation summary:
# Source: MAC=“b0:c1:d2:e3:f4:a5”, IP=“192.168.11.10” // Destination: MAC=“a5:f4:e3:d2:c1:b0” // Wanted: IP= “192.168.11.20”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“c2:d3:e4:f5:a6:b7”, IP=“10.10.110.1” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “10.10.110.2”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 28
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 29)
# This is a conversation summary:
# Source: MAC=“02:00:4C:4F:4F:50”, IP=“13.177.238.85” // Destination: MAC=“d4:c3:b2:a1:f0:e9” // Wanted: IP= “13.177.238.86”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 29
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 30)
# This is a conversation summary:
# Source: MAC=“02:00:4C:4F:4F:50”, IP=“13.177.238.85” // Destination: MAC=“d4:c3:b2:a1:f0:e9” // Wanted: IP= “13.177.238.86”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:5A:3C:7A:5B”, IP=“254.108.157.151” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “254.108.157.157”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 30
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 31)
# This is a conversation summary:
# Source: MAC=“02:00:6B:1D:EE:FF”, IP=“87.97.154.72” // Destination: MAC=“f8:e7:d6:c5:b4:a3” // Wanted: IP= “87.97.154.78”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 31
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 32)
# This is a conversation summary:
# Source: MAC=“02:00:6B:1D:EE:FF”, IP=“87.97.154.72” // Destination: MAC=“f8:e7:d6:c5:b4:a3” // Wanted: IP= “87.97.154.78”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:7E:9A:BC:DD”, IP=“165.243.166.55” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “165.243.166.53”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 32
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 33)
# This is a conversation summary:
# Source: MAC=“02:00:8F:AB:CD:EF”, IP=“177.132.83.183” // Destination: MAC=“b2:a1:f0:e9:d8:c7” // Wanted: IP= “177.132.83.183”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 33
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 34)
# This is a conversation summary:
# Source: MAC=“02:00:8F:AB:CD:EF”, IP=“177.132.83.183” // Destination: MAC=“b2:a1:f0:e9:d8:c7” // Wanted: IP= “177.132.83.183”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:9D:FA:CE:B0”, IP=“104.176.101.169” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “104.176.101.170”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 34
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 35)
# This is a conversation summary:
# Source: MAC=“02:00:AF:FE:C0:DE”, IP=“17.37.218.57” // Destination: MAC=“d6:c5:b4:a3:f2:e1” // Wanted: IP= “17.37.218.56”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 35
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 36)
# This is a conversation summary:
# Source: MAC=“02:00:AF:FE:C0:DE”, IP=“17.37.218.57” // Destination: MAC=“d6:c5:b4:a3:f2:e1” // Wanted: IP= “17.37.218.56”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:BA:AD:BE:EF”, IP=“205.101.233.55” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “205.101.233.58”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 36
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 37)
# This is a conversation summary:
# Source: MAC=“02:00:CA:FE:BA:BE”, IP=“9.245.99.169” // Destination: MAC=“f0:e9:d8:c7:b6:a5” // Wanted: IP= “9.245.99.166”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 37
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 38)
# This is a conversation summary:
# Source: MAC=“02:00:CA:FE:BA:BE”, IP=“9.245.99.169” // Destination: MAC=“f0:e9:d8:c7:b6:a5” // Wanted: IP= “9.245.99.166”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:DA:7A:5A:55”, IP=“10.42.95.146” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “10.42.95.148”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 38
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 39)
# This is a conversation summary:
# Source: MAC=“02:00:EA:10:10:10”, IP=“28.132.164.106” // Destination: MAC=“b4:a3:f2:e1:d0:c9” // Wanted: IP= “28.132.164.107”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 39
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 40)
# This is a conversation summary:
# Source: MAC=“02:00:EA:10:10:10”, IP=“28.132.164.106” // Destination: MAC=“b4:a3:f2:e1:d0:c9” // Wanted: IP= “28.132.164.107”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:FB:20:20:20”, IP=“215.34.86.205” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “215.34.86.208”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 40
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 41)
# This is a conversation summary:
# Source: MAC=“02:00:0C:30:30:30”, IP=“37.21.246.92” // Destination: MAC=“e7:d6:c5:b4:a3:f2” // Wanted: IP= “37.21.246.93”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 41
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 42)
# This is a conversation summary:
# Source: MAC=“02:00:0C:30:30:30”, IP=“37.21.246.92” // Destination: MAC=“e7:d6:c5:b4:a3:f2” // Wanted: IP= “37.21.246.93”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:1D:40:40:40”, IP=“134.5.120.94” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “134.5.120.95”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 42
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 43)
# This is a conversation summary:
# Source: MAC=“02:00:2E:50:50:50”, IP=“57.84.180.16” // Destination: MAC=“a1:f0:e9:d8:c7:b6” // Wanted: IP= “57.84.180.19”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 43
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 44)
# This is a conversation summary:
# Source: MAC=“02:00:2E:50:50:50”, IP=“57.84.180.16” // Destination: MAC=“a1:f0:e9:d8:c7:b6” // Wanted: IP= “57.84.180.19”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:3F:60:60:60”, IP=“112.45.219.244” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “112.45.219.248”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 44
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 45)
# This is a conversation summary:
# Source: MAC=“02:00:4A:70:70:70”, IP=“118.155.159.112” // Destination: MAC=“c5:b4:a3:f2:e1:d0” // Wanted: IP= “118.155.159.115”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 45
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 46)
# This is a conversation summary:
# Source: MAC=“02:00:4A:70:70:70”, IP=“118.155.159.112” // Destination: MAC=“c5:b4:a3:f2:e1:d0” // Wanted: IP= “118.155.159.115”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:5B:80:80:80”, IP=“9.202.229.0” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “9.202.229.5”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 46
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 47)
# This is a conversation summary:
# Source: MAC=“02:00:6C:90:90:90”, IP=“209.185.89.18” // Destination: MAC=“e9:d8:c7:b6:a5:f4” // Wanted: IP= “209.185.89.19”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 47
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 48)
# This is a conversation summary:
# Source: MAC=“02:00:6C:90:90:90”, IP=“209.185.89.18” // Destination: MAC=“e9:d8:c7:b6:a5:f4” // Wanted: IP= “209.185.89.19”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:7D:A0:A0:A0”, IP=“221.114.99.90” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “221.114.99.93”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 48
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 49)
# This is a conversation summary:
# Source: MAC=“02:00:8E:B0:B0:B0”, IP=“120.179.57.223” // Destination: MAC=“a3:f2:e1:d0:c9:b8” // Wanted: IP= “120.179.57.224”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 49
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 50)
# This is a conversation summary:
# Source: MAC=“02:00:8E:B0:B0:B0”, IP=“120.179.57.223” // Destination: MAC=“a3:f2:e1:d0:c9:b8” // Wanted: IP= “120.179.57.224”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:9F:C0:C0:C0”, IP=“128.144.56.70” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “128.144.56.78”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 50
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 51)
# This is a conversation summary:
# Source: MAC=“02:00:A0:D0:D0:D0”, IP=“109.41.52.18” // Destination: MAC=“c7:b6:a5:f4:e3:d2” // Wanted: IP= “109.41.52.17”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 51
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 52)
# This is a conversation summary:
# Source: MAC=“02:00:A0:D0:D0:D0”, IP=“109.41.52.18” // Destination: MAC=“c7:b6:a5:f4:e3:d2” // Wanted: IP= “109.41.52.17”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC=“02:00:B1:E0:E0:E0”, IP=“110.139.223.25” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “110.139.223.24”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 52
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 53)
# This is a conversation summary:
# Source: MAC=“02:00:C2:F0:F0:F0”, IP=“161.122.196.250” // Destination: MAC=“e1:d0:c9:b8:a7:f6” // Wanted: IP= “161.122.196.253”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 53
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 54)
# This is a conversation summary:
# Source: MAC=“02:00:C2:F0:F0:F0”, IP=“161.122.196.250” // Destination: MAC=“e1:d0:c9:b8:a7:f6” // Wanted: IP= “161.122.196.253”
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# ...
# This is a conversation summary:
# Source: MAC="02:00:4C:4F:4F:50", IP="192.168.1.1" // Destination: MAC="02:00:5A:3C:7A:5B" // Wanted: IP="192.168.1.2"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC="02:00:6B:1D:EE:FF", IP="192.168.1.3" // Destination: MAC="FF:FF:FF:FF:FF:FF" // Wanted: IP="192.168.1.4"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 58
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 59)
# This is a conversation summary:
# Source: MAC="02:00:7E:9A:BC:DD", IP="192.168.1.5" // Destination: MAC="02:00:8F:AB:CD:EF" // Wanted: IP="192.168.1.6"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 59
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 60)
# This is a conversation summary:
# Source: MAC="02:00:7E:9A:BC:DD", IP="192.168.1.5" // Destination: MAC="02:00:8F:AB:CD:EF" // Wanted: IP="192.168.1.6"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC="02:00:9D:FA:CE:B0", IP="192.168.1.7" // Destination: MAC="FF:FF:FF:FF:FF:FF" // Wanted: IP="192.168.1.8"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 60
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 61)
# This is a conversation summary:
# Source: MAC="02:00:AF:FE:C0:DE", IP="192.168.1.9" // Destination: MAC="02:00:BA:AD:BE:EF" // Wanted: IP="192.168.1.10"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 61
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 62)
# This is a conversation summary:
# Source: MAC="02:00:AF:FE:C0:DE", IP="192.168.1.9" // Destination: MAC="02:00:BA:AD:BE:EF" // Wanted: IP="192.168.1.10"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC="02:00:CA:FE:BA:BE", IP="192.168.1.11" // Destination: MAC="FF:FF:FF:FF:FF:FF" // Wanted: IP="192.168.1.12"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 62
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 63)
# This is a conversation summary:
# Source: MAC="02:00:DA:7A:5A:55", IP="192.168.1.13" // Destination: MAC="02:00:EA:10:10:10" // Wanted: IP="192.168.1.14"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 63
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 64)
# This is a conversation summary:
# Source: MAC="02:00:DA:7A:5A:55", IP="192.168.1.13" // Destination: MAC="02:00:EA:10:10:10" // Wanted: IP="192.168.1.14"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC="02:00:FB:20:20:20", IP="192.168.1.15" // Destination: MAC="FF:FF:FF:FF:FF:FF" // Wanted: IP="192.168.1.16"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 64
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 65)
# This is a conversation summary:
# Source: MAC="02:00:0C:30:30:30", IP="192.168.1.17" // Destination: MAC="02:00:1D:40:40:40" // Wanted: IP="192.168.1.18"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 65
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 66)
# This is a conversation summary:
# Source: MAC="02:00:0C:30:30:30", IP="192.168.1.17" // Destination: MAC="02:00:1D:40:40:40" // Wanted: IP="192.168.1.18"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC="02:00:2E:50:50:50", IP="192.168.1.19" // Destination: MAC="FF:FF:FF:FF:FF:FF" // Wanted: IP="192.168.1.20"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 66
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 67)
# This is a conversation summary:
# Source: MAC="02:00:3F:60:60:60", IP="192.168.1.21" // Destination: MAC="02:00:4A:70:70:70" // Wanted: IP="192.168.1.22"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 67
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 68)
# This is a conversation summary:
# Source: MAC="02:00:3F:60:60:60", IP="192.168.1.21" // Destination: MAC="02:00:4A:70:70:70" // Wanted: IP="192.168.1.22"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC="02:00:5B:80:80:80", IP="192.168.1.23" // Destination: MAC="FF:FF:FF:FF:FF:FF" // Wanted: IP="192.168.1.24"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 68
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 69)
# This is a conversation summary:
# Source: MAC="02:00:6C:90:90:90", IP="192.168.1.25" // Destination: MAC="02:00:7D:A0:A0:A0" // Wanted: IP="192.168.1.26"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 69
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 70)
# This is a conversation summary:
# Source: MAC="02:00:6C:90:90:90", IP="192.168.1.25" // Destination: MAC="02:00:7D:A0:A0:A0" // Wanted: IP="192.168.1.26"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC="02:00:8E:B0:B0:B0", IP="192.168.1.27" // Destination: MAC="FF:FF:FF:FF:FF:FF" // Wanted: IP="192.168.1.28"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 70
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 71)
# This is a conversation summary:
# Source: MAC="02:00:9F:C0:C0:C0", IP="192.168.1.29" // Destination: MAC="02:00:A0:D0:D0:D0" // Wanted: IP="192.168.1.30"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 71
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 72)
# This is a conversation summary:
# Source: MAC="02:00:9F:C0:C0:C0", IP="192.168.1.29" // Destination: MAC="02:00:A0:D0:D0:D0" // Wanted: IP="192.168.1.30"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC="02:00:B1:E0:E0:E0", IP="192.168.1.31" // Destination: MAC="FF:FF:FF:FF:FF:FF" // Wanted: IP="192.168.1.32"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 72
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 73)
# This is a conversation summary:
# Source: MAC="02:00:C2:F0:F0:F0", IP="192.168.1.33" // Destination: MAC="02:00:D3:AA:AA:AA" // Wanted: IP="192.168.1.34"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 73
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 74)
# This is a conversation summary:
# Source: MAC="02:00:C2:F0:F0:F0", IP="192.168.1.33" // Destination: MAC="02:00:D3:AA:AA:AA" // Wanted: IP="192.168.1.34"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
# This is a conversation summary:
# Source: MAC="02:00:E4:BB:BB:BB", IP="192.168.1.35" // Destination: MAC="FF:FF:FF:FF:FF:FF" // Wanted: IP="192.168.1.36"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code.Dont give back any comments or imports, just bare code and commands. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC=...
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 74
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 75)
# This is a conversation summary:
# Source: MAC="02:00:F5:CC:CC:CC", IP="192.168.1.37" // Destination: MAC="02:00:06:DD:DD:DD" // Wanted: IP="192.168.1.38
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. This is extremely important. Dont start the resposnses wiht ```python This is a flagrant error.
#
# Use the following structure:
# pkt_1=...
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=...
#
# ...Generated!
# Number of completitions done: 75

# %%
# Generate random MAC address
import random
mac = [random.randint(0x00, 0xff) for i in range(6)]
mac[0] = (mac[0] & 0xfc) | 0x02 # Set the second bit to 1 to indicate a locally administered MAC address
mac = ":".join(map(lambda x: "%02x" % x, mac))

# Create request packet
request_pkt = scapy.Ether(src=mac, dst="FF:FF:FF:FF:FF:FF")/scapy.ARP(op=1, pdst="192.168.4.20", psrc="192.168.4.10", hwdst="00:00:00:00:00:00", hwsrc=mac)

# Create reply packet
reply_pkt = scapy.Ether(src=mac, dst=mac)/scapy.ARP(op=2, psrc="192.168.4.20", hwsrc=mac, hwdst=mac, pdst="192.168.4.10")

# Add packets to list
pkt_list = [request_pkt, reply_pkt]

# %%
# Este es el resumen de lo que está en el struct de responses para la última petición
print(responses[-1].prompt_summary)
print(responses[-1].completion.choices[0].text)
# Out:
# Source: MAC=“f3:a4:b5:c6:d7:e8”, IP=“172.16.3.10” // Destination: MAC=“FF:FF:FF:FF:FF:FF” // Wanted: IP= “172.16.3.20”
#
#
#
# import scapy.all as scapy
#
# # Generate random MAC address for the responding end
# import random
# mac = [random.randint(0x00, 0xff) for i in range(6)]
# mac[0] |= 0x02
# mac = ":".join(["%02x" % x for x in mac])
#
# # Create request packet
# request_pkt = scapy.Ether(src="f3:a4:b5:c6:d7:e8", dst="FF:FF:FF:FF:FF:FF")/scapy.ARP(op=1, pdst="172.16.3.20", psrc="172.16.3.10", hwdst="00:00:00:00:00:00", hwsrc="f3:a4:b5:c6:d7:e8")
#
# # Create reply packet
# reply_pkt = scapy.Ether(src=mac, dst="f3:a4:b5:c6:d7:e8")/scapy.ARP(op=2, psrc="172.16.3.20", hwsrc=mac, hwdst="f3:a4:b5:c6:d7:e8", pdst="172.16.3.10")
#
# # Add packets to list
# pkt_list = [request_pkt, reply_pkt]

# %%
#Esta es la forma que tiene una respuesta del modelo de IA
print(responses[-1].completion)
# Out:
# Completion(id='cmpl-92FB5D7MemVeJpZlaomyjw2L6FG9x', choices=[CompletionChoice(finish_reason='stop', index=0, logprobs=None, text='\n\nimport scapy.all as scapy\n\n# Generate random MAC address for the responding end\nimport random\nmac = [random.randint(0x00, 0xff) for i in range(6)]\nmac[0] |= 0x02\nmac = ":".join(["%02x" % x for x in mac])\n\n# Create request packet\nrequest_pkt = scapy.Ether(src="f3:a4:b5:c6:d7:e8", dst="FF:FF:FF:FF:FF:FF")/scapy.ARP(op=1, pdst="172.16.3.20", psrc="172.16.3.10", hwdst="00:00:00:00:00:00", hwsrc="f3:a4:b5:c6:d7:e8")\n\n# Create reply packet\nreply_pkt = scapy.Ether(src=mac, dst="f3:a4:b5:c6:d7:e8")/scapy.ARP(op=2, psrc="172.16.3.20", hwsrc=mac, hwdst="f3:a4:b5:c6:d7:e8", pdst="172.16.3.10")\n\n# Add packets to list\npkt_list = [request_pkt, reply_pkt]')], created=1710322027, model='gpt-3.5-turbo-instruct', object='text_completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=274, prompt_tokens=455, total_tokens=729))

# %% [markdown]
# ### Generación de paquetes

# %%
# Ejecutamos los comandos que devuelve el modelo para generar los paquetes
exec(responses[-1].completion.choices[0].text)
print(pkt_list)
# Out:
# [<Ether  dst=FF:FF:FF:FF:FF:FF src=f3:a4:b5:c6:d7:e8 type=ARP |<ARP  op=who-has hwsrc=f3:a4:b5:c6:d7:e8 psrc=172.16.3.10 hwdst=00:00:00:00:00:00 pdst=172.16.3.20 |>>, <Ether  dst=f3:a4:b5:c6:d7:e8 src=e7:44:42:a0:65:a0 type=ARP |<ARP  op=is-at hwsrc=e7:44:42:a0:65:a0 psrc=172.16.3.20 hwdst=f3:a4:b5:c6:d7:e8 pdst=172.16.3.10 |>>]

# %%
#Enviarlos para probar si se envian correctamente
send(pkt_list)
# Out:
# Sent 2 packets.

# %% [markdown]
# ### Introducción en un pcap

# %%
# Guardamos los paquetes generados en un pcap
with open("../../data/Conversations/ARP/pcap/ARPgenerated_3_5_turbo-instruct_conv.pcap", "ba+") as f:
    wrpcap(f, pkt_list, append=True)
