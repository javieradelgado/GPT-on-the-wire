# %% [markdown]
# # MOE architecture
# ----
#
# This notebook will have the basics of a AI MOE system where each expert is specilized in a single protocol and is able to create single packages of that protocol.
#
# <center><img src="https://www.datocms-assets.com/96965/1695407447-image1.png">

# %% [markdown]
# #### Imports

# %%
import os
os.environ['OPENAI_API_KEY'] = 'FILL'

import openai
from openai import OpenAI
client = OpenAI()

import random
import re
import pickle
import scapy
import toml
import ipaddress
import json

from scapy.all import *
from scapy.utils import RawPcapReader, wrpcap
import scapy.all as scapy
from scapy.layers.l2 import Ether, ARP
from scapy.layers.inet import IP, ICMP
from scapy.layers.http import *

# %% [markdown]
# #### Definitions

# %%
ip_file = "../../scripts/sample_input/ip_file.toml"
mac_file = "../../scripts/sample_input/mac_file.txt"
resource_file = "../../scripts/sample_input/resource_file.txt"

functioning ="Conversations"

number_of_creations = 5
protocols = ["ICMP", "ARP", "DNS", "HTTP"]
HTTPCodes = [200, 307, 403, 404]
HTTPPhrases = ["OK", "Temporary Redirect", "Forbidden", "Not Found"]


Models_file = 'Models.jsonl'
pkl_saved = "../../data/MOE/pickle/MOE_v3_Conversations_Fine_Tuned_v3.pkl"
pcap_saved = "../../data/MOE/pcap/MOE_v3_Conversations_generated_3_5_turbo-instruct_conv_v3.pcap"

system_message = 'You are a new generation traffic generator. \
You are specilized in the {} protocol and {} generation using python and scapy. \
You are especially attentive to variables and different types of traffic.'

# %% [markdown]
# ## Step 1: Important functions definition

# %% [markdown]
# #### load_toml:
# Lee y procesa un paquete toml definido por el usuario. Este paquete Toml es donde están las IPs de diferentes redes, un equipo victima y otro atacante.

# %%
def load_toml(ip_file):
    network_ips = []
    victim_ip = ""
    attacker_ip = ""
    with open(ip_file, "r") as f:
        data = toml.load(f)
        for ip_desc in data['network']['ip']:
            # Convierte cada elemento en un objeto de red IP usando la función ipaddress.ip_network
            # Elimina los espacios en blanco al principio y al final del elemento con el método strip
            # Usa el método hosts para obtener una lista de los hosts de la red
            # Añade los hosts a la lista network_ips con el método extend
            network_ips.extend(ipaddress.ip_network(ip_desc.strip()).hosts())
        victim_ip = ipaddress.ip_network(data['victim']['ip'].strip()).hosts()
        attacker_ip = ipaddress.ip_network(
            data['attacker']['ip'].strip()).hosts()

    return network_ips, victim_ip, attacker_ip

# %%
def load_txt(file):
    with open(file,"r") as f:
        return f.read().splitlines()

# %% [markdown]
# #### generate_packet_summaries:
#
# Esto es un generador automático de resumenes de paquetes basado en la aleatoriedad de la función random.choice()
# Solo es capaz de generar resuemenes de tráfico ICMP y DNS, en teoría los elige de los protocolos en la lista protocols pero solo se pueden generar esos 2
# Para generar resumenes selecciona aleatoriamente 2 ips de una lista de IPs que se le pasa
# Tambien elige aleatoriamente el resto de variables de los paquetes como son la id, sqe, longitud
# Por cada paquete generado se aumenta en 2 el ctr
# EL generador se para cuando se cumple la condición del ctr, esta condición depende de la variable n que se le pase

# %%
def generate_packet_summaries(ip_list, n, protocols, mac_list=None, resource_list=None):
    summaries = []
    ctr = 0
    while ctr < math.ceil(n/5)*5:
        proto = random.choice(protocols)
        if proto == "ICMP":
            ip1, ip2 = random.choices(ip_list, k=2)
            random_id, random_seq = random.randint(
                0, 65535), random.randint(0, 65535)
            random_length = random.choice([76, 100])
            summaries.append(
                "{} → {} ICMP {} (ping) request id={:#06x}, seq={}".format(
                    ip1, ip2, random_length, random_id, random_seq))
            summaries.append(
                "{} → {} ICMP {} (ping) reply id={:#06x}, seq={}".format(
                    ip2, ip1, random_length, random_id, random_seq))
            ctr += 2
        elif proto == "ARP":
            mac1, mac2 = random.choices(mac_list, k=2)
            if mac2 == "FF:FF:FF:FF:FF:FF":
                mac3 = random.choices(mac_list, k=2)
            else:
                if  random.choice([0, 10]) < 5:
                    mac3 = mac2
                else:
                    mac3 =  random.choices(mac_list, k=1)
                    while mac3 == "FF:FF:FF:FF:FF:FF" or mac3 == mac1:
                        mac3 =  random.choices(ordest_list, k=1)
            
            ip1, ip2 = random.choices(ip_list, k=2)
            
            random_length = random.choice([76, 100])
            summaries.append(
                "{}     {}     ARP      {}     Who has {}? Tell {}".format(
                    mac1, mac2, random_length, ip1, ip2))
            summaries.append(
                "{}     {}     ARP      {}     {} is at {}".format(
                    mac3, mac1, random_length, ip1, mac3))
            ctr += 2
    return summaries

# %% [markdown]
# #### generate_conversation_summaries:
#
# Esto es un generador automático de resumenes de conversaciones basado en la aleatoriedad de la función random.choice()
# Solo es capaz de generar resuemenes de tráfico ICMP, ARP y DNS, en teoría los elige de los protocolos en la lista protocols pero solo se pueden generar esos 3.
# Para generar resumenes seleccionan aleatoriamente las ips de una lista de IPs que se le pasa.
# Tambien elige aleatoriamente el resto de variables de los paquetes como son la id, sqe, longitud.
# Por cada paquete generado se aumenta en 2 el ctr.
# EL generador se para cuando se cumple la condición del ctr, esta condición depende de la variable n que se le pase.

# %%
def generate_conversation_summaries(ip_list, n, protocols, mac_list=None, resource_list=None):
    summaries = []
    ctr = 0
    while ctr < n:
        proto = random.choice(protocols)
        
        if proto == "ICMP":
            ip1, ip2 = random.choices(ip_list, k=2)
            random_id, random_seq = random.randint(
                0, 65535), random.randint(0, 65535)
            random_type = random.choice(["Echo", "Timestamp"])
            summaries.append(
                "Source: IP={} // Destination: IP={} // Others: id={:#06x} seq= {} type={}".format(
                    ip1, ip2, random_id, random_seq, random_type))
            ctr += 1
        elif proto == "ARP":
            mac1, mac2 = random.choices(mac_list, k=2)
            
            while mac1 == "FF:FF:FF:FF:FF:FF":
                mac1 = random.choices(mac_list, k=1)
                
            ip1, ip2 = random.choices(ip_list, k=2)
            
            summaries.append(
                "Source: MAC={}, IP={} // Destination: MAC={} // Wanted: IP= {}".format(
                    mac1, ip1, mac2, ip2))
            ctr += 1
            
        elif proto == "DNS":
            
            ip1, ip2, ip3 = random.choices(ip_list, k=3)
            random_id = random.randint(0, 65535)
            random_resource = random.choices(resource_list, k=1)
            
            summaries.append(
            "Source: IP= {} // Destination: IP= {} // Others: {:#06x} , resource= {} , response = {}".format(
                    ip1, ip2, random_id, random_resource, ip3))
            
            ctr += 1
            
        elif proto == "HTTP":
            
            ip1, ip2= random.choices(ip_list, k=2)
            port1 = random.randint(1025, 65535)
            window1, window2 = random.randint(200, 6535), random.randint(200, 6535)
            random_resource = random.choices(resource_list, k=1)
            index = random.randint(0, 3)
            code = HTTPCodes[index]
            ReasonPhrase = HTTPPhrases[index]
            
            summaries.append(
            "Source: IP={}, port={}, Window: {} // Destination: IP={}, port=80, Window: {} // Others: Host={}, Path="", Code={}, Reason_Phrase= {}".format(
                    ip1, port1, window1, ip2, window2, random_resource, code, ReasonPhrase))
            
            
            ctr += 1
            
    return summaries

# %% [markdown]
# #### generate_ping_flood_summaries
# Al contrario que el generador anterior, este sirve para generar un ataque de ping flood a una victima en concreto
# También basado en probabilidad, si es True, se envía trafico maligno a la victima desde el atacante, si no, tráfico normal de la red con 2 equipos aleatorios
# Si es tráfico normal, se genera tanto la petición como la respuesta

# %%
def generate_ping_flood_summaries(ip_list, n, victim_ip, attacker_ip):
    summaries = []
    ctr = 0
    while ctr < math.ceil(n/5)*5:
        malicious = random.choices([True, False], weights=[0.7, 0.3], k=1)
        if malicious[0]: #Si es True
            random_id, random_seq = random.randint(
                0, 65535), random.randint(0, 65535)
            random_length = random.choice([76, 100])
            summaries.append(
                "{} → {} ICMP {} (ping) request id={:#06x}, seq={}".format(
                    attacker_ip, victim_ip, random_length, random_id, random_seq))
            ctr += 1
        else:
            ip1, ip2 = random.choices(ip_list, k=2)
            random_id, random_seq = random.randint(
                0, 65535), random.randint(0, 65535)
            random_length = random.choice([76, 100])
            summaries.append(
                "{} → {} ICMP {} (ping) request id={:#06x}, seq={}".format(
                    ip1, ip2, random_length, random_id, random_seq))
            summaries.append(
                "{} → {} ICMP {} (ping) reply id={:#06x}, seq={}".format(
                    ip2, ip1, random_length, random_id, random_seq))
            ctr += 2
    return summaries

# %% [markdown]
# #### generate_packets
#
# Se envian resumenes de paquetes de 5 en 5 al modelo, para ello se usa la variable ctr
# Se obtiene la lista de comandos de Scapy y antes de ejecutarla se añade una instrucción para anexar los paquetes creados a una lista grande npackets
# luego se ejecutan todas las instrcciones y se devuelven los paquetes

# %%
def generate_packets(summaries):
    ctr = 1
    packets = []
    prompt = ""
    for summary in summaries:
        prompt += summary + "\n"
        protocol = obtain_Packet_protocol(summary)
    
        
        if protocol == "ICMP":
            messages=[{"role": "system", "content": system_message.format("ICMP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Packets"]["Specific"]["ICMP"])
            completion = client.chat.completions.create(
            model=Models_list[functioning]["Specific"]["ICMP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
        
        elif protocol == "ARP":
            messages=[{"role": "system", "content": system_message.format("ARP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Packets"]["Specific"]["ARP"])
            completion = client.chat.completions.create(
            model=Models_list[functioning]["Specific"]["ARP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
        
        elif protocol == "DNS":
            messages=[{"role": "system", "content": system_message.format("DNS", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Packets"]["Specific"]["DNS"])
            completion = client.chat.completions.create(
            model=Models_list[functioning]["Specific"]["DNS"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
        
        elif protocol == "HTTP":
            messages=[{"role": "system", "content": system_message.format("HTTP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Packets"]["Specific"]["HTTP"])
            completion = client.chat.completions.create(
            model=Models_list[functioning]["Specific"]["HTTP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
        
        
        responses.append(response(messages, completion))
        pickle.dump(responses, open(pkl_saved, "wb" ) )
        
        print("\t\t" + "Comand->  " + str(responses[-1].completion.choices[0].message.content))
        exec("packets.append(" + str(responses[-1].completion.choices[0].message.content + ")"))
        ctr += 1
    return packets

# %%
def obtain_Packet_protocol(summary):
    if "ICMP" in summary:
        return "ICMP"
    elif "ARP" in summary:
        return "ARP"
    elif "DNS" in summary:
        return "DNS"
    elif "HTTP" in summary:
        return "HTTP"
    else:
        raise TypeError("Unsupported protocol.")

# %%
paquetes = []
def exec_commands(commands):
    print(commands)
    exec(commands)
        
    if protocol != "HTTP":
        pkt_1.show()
        paquetes.append([pkt_1, pkt_2])
        del pkt_1, pkt_2
    else:
        pkt_1.show()
        paquetes.append([pkt_1, pkt_2, pkt_3, pkt_4, pkt_5, pkt_6, pkt_7, pkt_8, pkt_9, pkt_10, pkt_11])
        del pkt_1, pkt_2, pkt_3, pkt_4, pkt_5, pkt_6, pkt_7, pkt_8, pkt_9, pkt_10, pkt_11
    
    return paquetes

# %%
def generate_Conversations(summaries):
    
    ctr= 1
    packets = []
    prompt = ""
    for summary in summaries:
        prompt += summary + "\n"
        protocol = obtain_Conversation_protocol(summary)
        
        if protocol == "ICMP":
            messages=[{"role": "system", "content": system_message.format("ICMP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Conversations"]["Specific"]["ICMP"])
            completion = client.chat.completions.create(
            model=Models_list["Conversations"]["Specific"]["ICMP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
            
        elif protocol == "ARP":
            print("++++++++++++++++++++++++++++++++++++++++")
            messages=[{"role": "system", "content": system_message.format("ARP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Conversations"]["Specific"]["ARP"])
            completion = client.chat.completions.create(
            model=Models_list["Conversations"]["Specific"]["ARP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)

        elif protocol == "DNS":
            messages=[{"role": "system", "content": system_message.format("DNS", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Conversations"]["Specific"]["DNS"])
            completion = client.chat.completions.create(
            model=Models_list["Conversations"]["Specific"]["DNS"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
        
        elif protocol == "HTTP":
            messages=[{"role": "system", "content": system_message.format("HTTP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Conversations"]["Specific"]["HTTP"])
            completion = client.chat.completions.create(
            model=Models_list["Conversations"]["Specific"]["HTTP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
            
        
        responses.append(response(messages, completion))
        pickle.dump(responses, open(pkl_saved, "wb" ) )
        commands = responses[-1].completion.choices[0].message.content[1:]
        
        ldict = {}
        exec(commands,globals(),ldict)
        
        if protocol != "HTTP":
            packets.append([ldict['pkt_1'], ldict['pkt_2']])
            del ldict
        else:
            packets.append([ldict['pkt_1'], ldict['pkt_2'], ldict['pkt_3'], ldict['pkt_4'], ldict['pkt_5'], ldict['pkt_6'], ldict['pkt_7'], ldict['pkt_8'], ldict['pkt_9'], ldict['pkt_10'], ldict['pkt_11']])
            del ldict
        
        print("\t\t" + "Comand->  " + commands)
        
        ctr += 1
    return packets

# %%
def obtain_Conversation_protocol(summary):
    if "seq=" in summary:
        return "ICMP"
    elif "MAC=" in summary:
        return "ARP"
    elif "response" in summary:
        return "DNS"
    elif "Window:" in summary:
        return "HTTP"
    else:
        raise TypeError("Unsupported protocol.")

# %%
def write_pcap(packets, pcap_saved):
    for packet in packets:
        with open(pcap_saved, "ba+") as f:
            wrpcap(f, packet, append=True)

# %%
class response():
    "Stores name and place pairs"
    def __init__(self, name, place):
        self.prompt_summary = name
        self.completion = place

try:
    responses = pickle.load( open(pkl_saved, "rb" ))
except:
    responses = []

print("Number of previous responses: " + str(len(responses)))
# Out:
# Number of previous responses: 0

# %%
with open(Models_file, 'r') as json_file:
    Models_list = json.load(json_file)

print("\n---------------------------------------------------------")
print("                 Availiable PACKET models                  ")
print("---------------------------------------------------------\n")
for key, value in Models_list["Packets"]["Specific"].items():
    print( "\t" + key + " -> " + value)

print("\n---------------------------------------------------------")
print("             Availiable CONVERSATIONS models               ")
print("---------------------------------------------------------\n")
for key, value in Models_list["Conversations"]["Specific"].items():
    print( "\t" + key + " -> " + value)

print("\n---------------------------------------------------------")
print("                    Packet generation                    ")
print("---------------------------------------------------------\n")

network_ips, victim_ip, attacker_ip = load_toml(ip_file)
mac_list = load_txt(mac_file)
resource_list = load_txt(resource_file)

if functioning =="Packets":
    summaries = generate_packet_summaries(
            network_ips, n=100, protocols=protocols, mac_list=mac_list, resource_list=resource_list)
elif functioning =="Conversations":
    summaries = generate_conversation_summaries(
            network_ips, n=100, protocols=protocols, mac_list=mac_list, resource_list=resource_list)

print("Generated {} summaries:\n".format(len(summaries)))
for index in range(len(summaries)):
    print("\t" + str(index+1)+". " + summaries[index])

print("\n---------------------------------------------------------")
print("        Using OpenAI API to generate packets...          ")
print("---------------------------------------------------------\n")

packets =[]

if functioning =="Packets":
    packets = generate_packets(summaries)

elif functioning =="Conversations":
    packets = generate_Conversations(summaries)

print(packets)

print("\nGenerated {} packets.\nWriting them to {} ...".format(
        len(packets),
        pcap_saved))

write_pcap(packets, pcap_saved)
print("Done!")
# Out:
# ---------------------------------------------------------
#                  Availiable PACKET models
# ---------------------------------------------------------
#
# 	ICMPv1 -> ft:gpt-3.5-turbo-0125:personal:icmpv1:9ELvoktd
# 	ICMPv2 -> ft:gpt-3.5-turbo-1106:personal:icmpv2:9F2iiDZa
# 	DNS ->
# 	ARP -> ft:gpt-3.5-turbo-1106:personal:arpv1:9FLIvsUk
# 	ARPv2 -> ft:gpt-3.5-turbo-1106:personal:arpv2:9FPXrE3X
# 	HTTP ->
#
# ---------------------------------------------------------
#              Availiable CONVERSATIONS models
# ---------------------------------------------------------
#
# 	ICMP -> ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 	DNS -> ft:gpt-3.5-turbo-1106:personal:convdnsv2:9OT57bdn
# 	ARP -> ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 	HTTP -> ft:gpt-3.5-turbo-1106:personal:convhttpv4:9Tq7Cjjl
#
# ---------------------------------------------------------
#                     Packet generation
# ---------------------------------------------------------
#
# Generated 100 summaries:
#
# 	1. Source: IP=172.16.161.46 // Destination: IP=172.16.113.138 // Others: id=0xb92b seq= 21181 type=Timestamp
# 	2. Source: IP=10.0.147.228 // Destination: IP=172.16.10.168 // Others: id=0x3b79 seq= 48057 type=Timestamp
# 	3. Source: IP= 10.0.154.41 // Destination: IP= 172.16.62.246 // Others: 0x2c36 , resource= ['www.microsoft.com'] , response = 172.16.22.74
# 	4. Source: MAC=45:67:89:AB:CD:EF, IP=172.16.247.189 // Destination: MAC=EF:12:34:56:78:9A // Wanted: IP= 172.16.111.86
# 	5. Source: IP= 10.0.159.105 // Destination: IP= 172.16.218.232 // Others: 0xfd0c , resource= ['www.twitch.tv'] , response = 10.0.68.146
# 	6. Source: MAC=23:45:67:89:AB:CD, IP=172.16.201.220 // Destination: MAC=FF:FF:FF:FF:FF:FF // Wanted: IP= 10.0.197.24
# 	7. Source: MAC=EF:12:34:56:78:9A, IP=172.16.91.85 // Destination: MAC=05:3A:4B:5C:6D:7E // Wanted: IP= 172.16.175.183
# 	8. Source: IP=172.16.81.245, port=58944, Window: 6327 // Destination: IP=10.0.7.254, port=80, Window: 4908 // Others: Host=['www.adobe.com'], Path=, Code=307, Reason_Phrase= Temporary Redirect
# 	9. Source: IP= 172.16.245.33 // Destination: IP= 172.16.53.49 // Others: 0x558f , resource= ['www.live.com'] , response = 10.0.216.94
# 	10. Source: IP=172.16.186.198 // Destination: IP=10.0.71.86 // Others: id=0x88c2 seq= 14462 type=Echo
# 	11. Source: MAC=CD:EF:12:34:56:78, IP=172.16.112.224 // Destination: MAC=04:2F:3C:4D:5E:6F // Wanted: IP= 172.16.149.44
# 	12. Source: IP=172.16.94.135, port=57563, Window: 2301 // Destination: IP=172.16.10.182, port=80, Window: 4242 // Others: Host=['www.tumblr.com'], Path=, Code=404, Reason_Phrase= Not Found
# 	13. Source: MAC=DE:F1:23:45:67:89, IP=172.16.12.139 // Destination: MAC=67:89:AB:CD:EF:12 // Wanted: IP= 172.16.14.169
# 	14. Source: IP=10.0.8.120 // Destination: IP=172.16.34.51 // Others: id=0xdf86 seq= 56322 type=Echo
# 	15. Source: MAC=08:15:23:42:56:69, IP=10.0.102.22 // Destination: MAC=FF:FF:FF:FF:FF:FF // Wanted: IP= 10.0.17.94
# 	16. Source: IP=172.16.144.101, port=18560, Window: 6424 // Destination: IP=10.0.28.20, port=80, Window: 1250 // Others: Host=['www.stackoverflow.com'], Path=, Code=403, Reason_Phrase= Forbidden
# 	17. Source: MAC=BC:DE:F1:23:45:67, IP=172.16.94.41 // Destination: MAC=56:78:9A:BC:DE:F1 // Wanted: IP= 172.16.22.206
# 	18. Source: MAC=['04:2F:3C:4D:5E:6F'], IP=172.16.47.243 // Destination: MAC=67:89:AB:CD:EF:12 // Wanted: IP= 172.16.249.237
# 	19. Source: IP=172.16.58.139 // Destination: IP=172.16.48.113 // Others: id=0x3ce6 seq= 47383 type=Echo
# 	20. Source: MAC=45:67:89:AB:CD:EF, IP=10.0.77.242 // Destination: MAC=08:15:23:42:56:69 // Wanted: IP= 10.0.50.175
# 	21. Source: IP=10.0.127.110, port=31339, Window: 2891 // Destination: IP=172.16.178.14, port=80, Window: 1778 // Others: Host=['www.wordpress.com'], Path=, Code=200, Reason_Phrase= OK
# 	22. Source: MAC=F1:23:45:67:89:AB, IP=10.0.195.83 // Destination: MAC=0A:7A:8B:9C:AD:BE // Wanted: IP= 172.16.196.146
# 	23. Source: IP= 10.0.58.30 // Destination: IP= 10.0.159.208 // Others: 0xfb1d , resource= ['www.twitter.com'] , response = 10.0.153.176
# 	24. Source: MAC=BC:DE:F1:23:45:67, IP=10.0.88.106 // Destination: MAC=AB:CD:EF:12:34:56 // Wanted: IP= 10.0.26.120
# 	25. Source: MAC=02:0A:0F:1B:2E:3C, IP=10.0.197.120 // Destination: MAC=F1:23:45:67:89:AB // Wanted: IP= 172.16.137.65
# 	26. Source: IP=10.0.119.114, port=51544, Window: 1909 // Destination: IP=10.0.58.173, port=80, Window: 920 // Others: Host=['www.bing.com'], Path=, Code=200, Reason_Phrase= OK
# 	27. Source: IP=172.16.1.78, port=21911, Window: 2507 // Destination: IP=10.0.43.150, port=80, Window: 3062 // Others: Host=['www.facebook.com'], Path=, Code=307, Reason_Phrase= Temporary Redirect
# 	28. Source: IP=172.16.187.252, port=6325, Window: 3459 // Destination: IP=172.16.253.191, port=80, Window: 1417 // Others: Host=['www.github.com'], Path=, Code=307, Reason_Phrase= Temporary Redirect
# 	29. Source: IP=10.0.102.132, port=54201, Window: 5391 // Destination: IP=10.0.85.123, port=80, Window: 3322 // Others: Host=['www.ebay.com'], Path=, Code=404, Reason_Phrase= Not Found
# 	30. Source: MAC=56:78:9A:BC:DE:F1, IP=172.16.53.118 // Destination: MAC=78:9A:BC:DE:F1:23 // Wanted: IP= 172.16.65.238
# 	31. Source: IP= 10.0.82.92 // Destination: IP= 172.16.105.111 // Others: 0x3070 , resource= ['www.reddit.com'] , response = 172.16.108.28
# 	32. Source: MAC=09:6F:7A:8B:9C:AD, IP=10.0.12.141 // Destination: MAC=F1:23:45:67:89:AB // Wanted: IP= 10.0.222.199
# 	33. Source: IP=172.16.226.225 // Destination: IP=10.0.22.152 // Others: id=0x710d seq= 3761 type=Timestamp
# 	34. Source: MAC=23:45:67:89:AB:CD, IP=172.16.128.205 // Destination: MAC=CD:EF:12:34:56:78 // Wanted: IP= 172.16.116.66
# 	35. Source: IP=172.16.155.164, port=59143, Window: 4039 // Destination: IP=172.16.181.50, port=80, Window: 1128 // Others: Host=['www.gmail.com'], Path=, Code=307, Reason_Phrase= Temporary Redirect
# 	36. Source: IP=10.0.27.100 // Destination: IP=172.16.239.17 // Others: id=0xc5cc seq= 24102 type=Timestamp
# 	37. Source: IP=10.0.180.188 // Destination: IP=10.0.243.109 // Others: id=0x536f seq= 62814 type=Echo
# 	38. Source: IP=172.16.164.73, port=55783, Window: 3245 // Destination: IP=172.16.130.155, port=80, Window: 600 // Others: Host=['www.youtube.com'], Path=, Code=307, Reason_Phrase= Temporary Redirect
# 	39. Source: IP=172.16.139.151, port=2924, Window: 3876 // Destination: IP=172.16.247.90, port=80, Window: 5732 // Others: Host=['www.stackoverflow.com'], Path=, Code=403, Reason_Phrase= Forbidden
# 	40. Source: MAC=F1:23:45:67:89:AB, IP=10.0.2.42 // Destination: MAC=00:1A:2B:3C:4D:5E // Wanted: IP= 172.16.138.138
# 	41. Source: MAC=00:1A:2B:3C:4D:5E, IP=10.0.47.21 // Destination: MAC=03:1C:2D:3E:4F:50 // Wanted: IP= 10.0.132.160
# 	42. Source: IP=172.16.247.112 // Destination: IP=10.0.178.15 // Others: id=0xa3d2 seq= 5079 type=Timestamp
# 	43. Source: IP= 172.16.102.41 // Destination: IP= 10.0.163.76 // Others: 0xa1aa , resource= ['www.wordpress.com'] , response = 10.0.29.84
# 	44. Source: IP=172.16.127.225, port=61790, Window: 5220 // Destination: IP=172.16.87.145, port=80, Window: 1937 // Others: Host=['www.whatsapp.com'], Path=, Code=404, Reason_Phrase= Not Found
# 	45. Source: IP=172.16.205.251 // Destination: IP=172.16.67.73 // Others: id=0xd963 seq= 39409 type=Echo
# 	46. Source: IP=172.16.211.12, port=60149, Window: 401 // Destination: IP=172.16.116.141, port=80, Window: 5454 // Others: Host=['www.spotify.com'], Path=, Code=307, Reason_Phrase= Temporary Redirect
# 	47. Source: IP= 172.16.93.204 // Destination: IP= 10.0.145.215 // Others: 0x8dc4 , resource= ['www.github.com'] , response = 10.0.245.9
# 	48. Source: MAC=03:1C:2D:3E:4F:50, IP=172.16.29.128 // Destination: MAC=23:45:67:89:AB:CD // Wanted: IP= 172.16.81.9
# 	49. Source: MAC=05:3A:4B:5C:6D:7E, IP=172.16.219.182 // Destination: MAC=BC:DE:F1:23:45:67 // Wanted: IP= 172.16.37.30
# 	50. Source: IP=10.0.164.173 // Destination: IP=172.16.61.223 // Others: id=0xe5dd seq= 935 type=Timestamp
# 	51. Source: IP=172.16.102.128 // Destination: IP=10.0.24.247 // Others: id=0xd3eb seq= 2358 type=Timestamp
# 	52. Source: MAC=9A:BC:DE:F1:23:45, IP=10.0.86.235 // Destination: MAC=04:2F:3C:4D:5E:6F // Wanted: IP= 10.0.137.116
# 	53. Source: IP=172.16.212.132 // Destination: IP=10.0.92.38 // Others: id=0xc839 seq= 53665 type=Timestamp
# 	54. Source: MAC=AB:CD:EF:12:34:56, IP=10.0.37.4 // Destination: MAC=08:15:23:42:56:69 // Wanted: IP= 10.0.53.121
# 	55. Source: MAC=56:78:9A:BC:DE:F1, IP=10.0.49.2 // Destination: MAC=34:56:78:9A:BC:DE // Wanted: IP= 172.16.151.235
# 	56. Source: IP=10.0.147.49 // Destination: IP=172.16.10.100 // Others: id=0x2658 seq= 3308 type=Timestamp
# 	57. Source: MAC=12:34:56:78:9A:BC, IP=172.16.133.239 // Destination: MAC=02:0A:0F:1B:2E:3C // Wanted: IP= 172.16.142.48
# 	58. Source: IP= 10.0.49.106 // Destination: IP= 172.16.179.131 // Others: 0x5a99 , resource= ['www.qq.com'] , response = 172.16.120.93
# 	59. Source: IP=10.0.157.178 // Destination: IP=172.16.188.250 // Others: id=0xde52 seq= 55278 type=Echo
# 	60. Source: IP=172.16.39.252 // Destination: IP=10.0.47.161 // Others: id=0xa079 seq= 17474 type=Echo
# 	61. Source: IP=10.0.2.70 // Destination: IP=172.16.8.222 // Others: id=0x573d seq= 9540 type=Echo
# 	62. Source: IP= 10.0.218.31 // Destination: IP= 10.0.175.181 // Others: 0x59b2 , resource= ['www.spotify.com'] , response = 10.0.24.225
# 	63. Source: MAC=00:1A:2B:3C:4D:5E, IP=10.0.138.66 // Destination: MAC=45:67:89:AB:CD:EF // Wanted: IP= 172.16.189.150
# 	64. Source: IP= 10.0.238.39 // Destination: IP= 192.168.1.89 // Others: 0x86c7 , resource= ['www.youtube.com'] , response = 10.0.33.139
# 	65. Source: IP= 172.16.103.123 // Destination: IP= 10.0.144.205 // Others: 0x172e , resource= ['www.etsy.com'] , response = 172.16.87.113
# 	66. Source: MAC=0A:7A:8B:9C:AD:BE, IP=10.0.4.119 // Destination: MAC=AB:CD:EF:12:34:56 // Wanted: IP= 10.0.5.36
# 	67. Source: IP=10.0.19.114 // Destination: IP=172.16.162.142 // Others: id=0x2d0f seq= 23692 type=Echo
# 	68. Source: IP= 172.16.230.55 // Destination: IP= 10.0.145.125 // Others: 0xefb9 , resource= ['www.reddit.com'] , response = 172.16.246.198
# 	69. Source: IP= 10.0.12.115 // Destination: IP= 172.16.63.146 // Others: 0xae2e , resource= ['www.spotify.com'] , response = 10.0.176.105
# 	70. Source: IP=10.0.25.65, port=56211, Window: 459 // Destination: IP=172.16.181.174, port=80, Window: 3142 // Others: Host=['www.wordpress.com'], Path=, Code=307, Reason_Phrase= Temporary Redirect
# 	71. Source: MAC=02:0A:0F:1B:2E:3C, IP=10.0.118.110 // Destination: MAC=23:45:67:89:AB:CD // Wanted: IP= 172.16.51.78
# 	72. Source: IP= 10.0.89.134 // Destination: IP= 10.0.131.23 // Others: 0x28df , resource= ['www.instagram.com'] , response = 172.16.22.79
# 	73. Source: IP= 10.0.197.208 // Destination: IP= 172.16.86.119 // Others: 0xd94a , resource= ['www.google.com'] , response = 172.16.218.46
# 	74. Source: IP=10.0.182.98 // Destination: IP=10.0.138.174 // Others: id=0xfa02 seq= 16348 type=Echo
# 	75. Source: IP= 172.16.8.5 // Destination: IP= 172.16.155.157 // Others: 0x19a8 , resource= ['www.tumblr.com'] , response = 10.0.95.188
# 	76. Source: MAC=06:4D:5E:6F:7A:8B, IP=10.0.58.152 // Destination: MAC=89:AB:CD:EF:12:34 // Wanted: IP= 10.0.96.28
# 	77. Source: IP=10.0.4.71, port=43266, Window: 6196 // Destination: IP=172.16.186.115, port=80, Window: 1424 // Others: Host=['www.live.com'], Path=, Code=404, Reason_Phrase= Not Found
# 	78. Source: MAC=09:6F:7A:8B:9C:AD, IP=10.0.150.125 // Destination: MAC=07:5E:6F:7A:8B:9C // Wanted: IP= 172.16.231.13
# 	79. Source: IP=172.16.195.118, port=48177, Window: 387 // Destination: IP=172.16.253.59, port=80, Window: 1336 // Others: Host=['www.craigslist.org'], Path=, Code=404, Reason_Phrase= Not Found
# 	80. Source: IP=172.16.133.207, port=49664, Window: 4422 // Destination: IP=172.16.204.4, port=80, Window: 3961 // Others: Host=['www.apple.com'], Path=, Code=200, Reason_Phrase= OK
# 	81. Source: MAC=23:45:67:89:AB:CD, IP=172.16.74.8 // Destination: MAC=03:1C:2D:3E:4F:50 // Wanted: IP= 10.0.29.86
# 	82. Source: IP=172.16.212.102, port=24266, Window: 2859 // Destination: IP=10.0.107.238, port=80, Window: 4591 // Others: Host=['www.twitter.com'], Path=, Code=307, Reason_Phrase= Temporary Redirect
# 	83. Source: MAC=04:2F:3C:4D:5E:6F, IP=172.16.122.102 // Destination: MAC=23:45:67:89:AB:CD // Wanted: IP= 172.16.242.107
# 	84. Source: IP=10.0.93.85, port=30999, Window: 1563 // Destination: IP=10.0.255.114, port=80, Window: 3233 // Others: Host=['www.bing.com'], Path=, Code=200, Reason_Phrase= OK
# 	85. Source: IP=172.16.238.77 // Destination: IP=172.16.240.246 // Others: id=0x562a seq= 58789 type=Timestamp
# 	86. Source: MAC=89:AB:CD:EF:12:34, IP=10.0.34.1 // Destination: MAC=DE:F1:23:45:67:89 // Wanted: IP= 172.16.99.145
# 	87. Source: IP= 10.0.162.77 // Destination: IP= 172.16.81.85 // Others: 0xa900 , resource= ['www.imdb.com'] , response = 10.0.248.22
# 	88. Source: IP=172.16.61.48, port=53608, Window: 4298 // Destination: IP=172.16.66.119, port=80, Window: 6218 // Others: Host=['www.craigslist.org'], Path=, Code=200, Reason_Phrase= OK
# 	89. Source: IP=172.16.88.77, port=40086, Window: 2540 // Destination: IP=10.0.245.186, port=80, Window: 1330 // Others: Host=['www.gmail.com'], Path=, Code=403, Reason_Phrase= Forbidden
# 	90. Source: IP=172.16.158.29 // Destination: IP=172.16.7.71 // Others: id=0x79b6 seq= 61309 type=Timestamp
# 	91. Source: IP=172.16.229.208 // Destination: IP=10.0.72.7 // Others: id=0x2f8b seq= 13 type=Echo
# 	92. Source: IP=172.16.209.132 // Destination: IP=172.16.141.243 // Others: id=0xaaf0 seq= 42964 type=Echo
# 	93. Source: IP=10.0.127.18, port=38975, Window: 349 // Destination: IP=10.0.88.249, port=80, Window: 6209 // Others: Host=['www.adobe.com'], Path=, Code=200, Reason_Phrase= OK
# 	94. Source: MAC=07:5E:6F:7A:8B:9C, IP=10.0.178.82 // Destination: MAC=02:0A:0F:1B:2E:3C // Wanted: IP= 172.16.0.12
# 	95. Source: IP=10.0.241.89 // Destination: IP=10.0.188.94 // Others: id=0xa0e2 seq= 39326 type=Echo
# 	96. Source: IP=172.16.175.53 // Destination: IP=172.16.25.78 // Others: id=0xaa59 seq= 59287 type=Timestamp
# 	97. Source: IP= 10.0.172.182 // Destination: IP= 10.0.149.140 // Others: 0x4c6f , resource= ['www.baidu.com'] , response = 10.0.96.27
# 	98. Source: IP=172.16.244.251, port=13118, Window: 1174 // Destination: IP=172.16.213.44, port=80, Window: 1180 // Others: Host=['www.google.com'], Path=, Code=404, Reason_Phrase= Not Found
# 	99. Source: MAC=78:9A:BC:DE:F1:23, IP=172.16.243.209 // Destination: MAC=CD:EF:12:34:56:78 // Wanted: IP= 10.0.131.230
# 	100. Source: IP= 172.16.35.242 // Destination: IP= 10.0.179.204 // Others: 0xd577 , resource= ['www.adobe.com'] , response = 10.0.49.108
#
# ---------------------------------------------------------
#         Using OpenAI API to generate packets...
# ---------------------------------------------------------
#
# 	1. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="172.16.161.46", dst="172.16.113.138")/scapy.ICMP(type=13, id=0xb92b, seq=21181)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="172.16.113.138", dst="172.16.161.46")/scapy.ICMP(type=14, id=0xb92b, seq=21181)
# 	2. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="10.0.147.228", dst="172.16.10.168")/scapy.ICMP(type=13, id=0x3b79, seq=48057)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="172.16.10.168", dst="10.0.147.228")/scapy.ICMP(type=14, id=0x3b79, seq=48057)
# 	3. Using->  ft:gpt-3.5-turbo-1106:personal:convdnsv2:9OT57bdn
# 		Comand->  RANDOM_PORT = random.randint(4097, 65530)
# pkt_1 = IP(src="10.0.154.41", dst="172.16.62.246")/UDP(sport=RANDOM_PORT, dport=53)/DNS(id=0x2c36, qr=0, rd=1, opcode=0, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.microsoft.com", qtype="A", qclass="IN"))
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2 = IP(src="172.16.62.246", dst="10.0.154.41")/UDP(sport=53, dport=RANDOM_PORT)/DNS(id=0x0aba, qr=1, opcode=0, ra=1, rcode=0, qdcount=1, ancount=1, nscount=0, arcount=0, qd=DNSQR(qname="www.microsoft.com", qtype="A", qclass="IN"), an=DNSRR(rrname="www.microsoft.com", type="A", rclass="IN", ttl=255, rdata="172.16.22.74"))
# ++++++++++++++++++++++++++++++++++++++++
# 	4. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="45:67:89:AB:CD:EF", dst="EF:12:34:56:78:9A")/scapy.ARP(op=1, pdst="172.16.111.86", psrc="172.16.247.189", hwdst="EF:12:34:56:78:9A", hwsrc="45:67:89:AB:CD:EF")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="EF:12:34:56:78:9A", dst="45:67:89:AB:CD:EF")/scapy.ARP(op=2, psrc="172.16.111.86", hwsrc="EF:12:34:56:78:9A", hwdst="45:67:89:AB:CD:EF", pdst="172.16.247.189")
# 	5. Using->  ft:gpt-3.5-turbo-1106:personal:convdnsv2:9OT57bdn
# 		Comand->  RANDOM_PORT = random.randint(4097, 65530)
# pkt_1 = IP(src="10.0.159.105", dst="172.16.218.232")/UDP(sport=RANDOM_PORT, dport=53)/DNS(id=0xfd0c, qr=0, rd=1, opcode=0, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.twitch.tv", qtype="A", qclass="IN"))
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2 = IP(src="172.16.218.232", dst="10.0.159.105")/UDP(sport=53, dport=RANDOM_PORT)/DNS(id=0x0aba, qr=1, opcode=0, ra=1, rcode=0, qdcount=1, ancount=1, nscount=0, arcount=0, qd=DNSQR(qname="www.twitch.tv", qtype="A", qclass="IN"), an=DNSRR(rrname="www.twitch.tv", type="A", rclass="IN", ttl=255, rdata="10.0.68.146"))
# ++++++++++++++++++++++++++++++++++++++++
# 	6. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="23:45:67:89:AB:CD", dst="FF:FF:FF:FF:FF:FF")/scapy.ARP(op=1, pdst="10.0.197.24", psrc="172.16.201.220", hwdst="00:00:00:00:00:00", hwsrc="23:45:67:89:AB:CD")
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC= "02:00:00:%02x:%02x:%02x" % (random.randint(0, 255),random.randint(0, 255),random.randint(0, 255))
# pkt_2=scapy.Ether(src=rand_MAC, dst="23:45:67:89:AB:CD")/scapy.ARP(op=2, psrc="10.0.197.24", hwsrc=rand_MAC, hwdst="23:45:67:89:AB:CD", pdst="172.16.201.220")
# ++++++++++++++++++++++++++++++++++++++++
# 	7. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="EF:12:34:56:78:9A", dst="05:3A:4B:5C:6D:7E")/scapy.ARP(op=1, pdst="172.16.175.183", psrc="172.16.91.85", hwdst="05:3A:4B:5C:6D:7E", hwsrc="EF:12:34:56:78:9A")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="05:3A:4B:5C:6D:7E", dst="EF:12:34:56:78:9A")/scapy.ARP(op=2, psrc="172.16.175.183", hwsrc="05:3A:4B:5C:6D:7E", hwdst="EF:12:34:56:78:9A", pdst="172.16.91.85")
# 	8. Using->  ft:gpt-3.5-turbo-1106:personal:convhttpv4:9Tq7Cjjl
# 		Comand->  x,y = random.sample(range(1, 100), 2)
# pkt_1= IP(src="172.16.81.245", dst="10.0.7.254")/TCP(sport=58944, dport=80, flags="S", seq=y, window=6327)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_1[TCP].payload)+1
# pkt_2= IP(src="10.0.7.254", dst="172.16.81.245")/TCP(sport=80, dport=58944, flags="SA", seq=x, ack=y, window=4908)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_2[TCP].payload)+1
# pkt_3= IP(src="172.16.81.245", dst="10.0.7.254")/TCP(sport=58944, dport=80, flags="A", seq=y, ack=x, window=6327)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_3[TCP].payload)
# pkt_4= IP(src="172.16.81.245",  dst="10.0.7.254") / TCP(sport=58944, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="www.adobe.com", Path="/")
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_4[TCP].payload)
# pkt_5= IP(src="10.0.7.254", dst="172.16.81.245")/TCP(sport=80, dport=58944, flags="A", seq=x, ack=y, window=4908)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_5[TCP].payload)
# pkt_6= IP(src="10.0.7.254",  dst="172.16.81.245") / TCP(sport=80, dport=58944, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "307", Reason_Phrase= "Temporary Redirect") / "<HTML><BODY><H1>Temporary Redirect</H1></BODY></HTML>"
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_6[TCP].payload)
# pkt_7= IP(src="172.16.81.245", dst="10.0.7.254")/TCP(sport=58944, dport=80, flags="A", seq=y, ack=x, window=6327)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_7[TCP].payload)
# pkt_8= IP(src="172.16.81.245", dst="10.0.7.254")/TCP(sport=58944, dport=80, flags="FA", seq=y, ack=x, window=6327)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_8[TCP].payload)
# pkt_9= IP(src="10.0.7.254", dst="172.16.81.245")/TCP(sport=80, dport=58944, flags="A", seq=x, ack=y+1, window=4908)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_9[TCP].payload)
# pkt_10= IP(src="10.0.7.254", dst="172.16.81.245")/TCP(sport=80, dport=58944, flags="FA", seq=x, ack=y+1, window=4908)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_10[TCP].payload)
# pkt_11= IP(src="172.16.81.245", dst="10.0.7.254")/TCP(sport=58944, dport=80, flags="A", seq=y+1, ack=x+1, window=6327)
# 	9. Using->  ft:gpt-3.5-turbo-1106:personal:convdnsv2:9OT57bdn
# 		Comand->  RANDOM_PORT = random.randint(4097, 65530)
# pkt_1 = IP(src="172.16.245.33", dst="172.16.53.49")/UDP(sport=RANDOM_PORT, dport=53)/DNS(id=0x558f, qr=0, rd=1, opcode=0, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.live.com", qtype="A", qclass="IN"))
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2 = IP(src="172.16.53.49", dst="10.0.216.94")/UDP(sport=53, dport=53)/DNS(id=0x0aba, qr=0, opcode=0, rd=1, ra=0, rcode=0, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.live.com", qtype="A", qclass="IN"))
# 	10. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="172.16.186.198", dst="10.0.71.86")/scapy.ICMP(type=8, id=0x88c2, seq=14462)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="10.0.71.86", dst="172.16.186.198")/scapy.ICMP(type=0, id=0x88c2, seq=14462)
# ++++++++++++++++++++++++++++++++++++++++
# 	11. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="CD:EF:12:34:56:78", dst="04:2F:3C:4D:5E:6F")/scapy.ARP(op=1, pdst="172.16.149.44", psrc="172.16.112.224", hwdst="04:2F:3C:4D:5E:6F", hwsrc="CD:EF:12:34:56:78")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="04:2F:3C:4D:5E:6F", dst="CD:EF:12:34:56:78")/scapy.ARP(op=2, psrc="172.16.149.44", hwsrc="04:2F:3C:4D:5E:6F", hwdst="CD:EF:12:34:56:78", pdst="172.16.112.224")
# 	12. Using->  ft:gpt-3.5-turbo-1106:personal:convhttpv4:9Tq7Cjjl
# 		Comand->  x,y = random.sample(range(1, 100), 2)
# pkt_1= IP(src="172.16.94.135", dst="172.16.10.182")/TCP(sport=57563, dport=80, flags="S", seq=y, window=2301)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_1[TCP].payload)+1
# pkt_2= IP(src="172.16.10.182", dst="172.16.94.135")/TCP(sport=80, dport=57563, flags="SA", seq=x, ack=y, window=4242)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_2[TCP].payload)+1
# pkt_3= IP(src="172.16.94.135", dst="172.16.10.182")/TCP(sport=57563, dport=80, flags="A", seq=y, ack=x, window=2301)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_3[TCP].payload)
# pkt_4= IP(src="172.16.94.135",  dst="172.16.10.182") / TCP(sport=57563, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="www.tumblr.com", Path="/")
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_4[TCP].payload)
# pkt_5= IP(src="172.16.10.182", dst="172.16.94.135")/TCP(sport=80, dport=57563, flags="A", seq=x, ack=y, window=4242)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_5[TCP].payload)
# pkt_6= IP(src="172.16.10.182",  dst="172.16.94.135") / TCP(sport=80, dport=57563, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "404", Reason_Phrase= "Not Found")
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_6[TCP].payload)
# pkt_7= IP(src="172.16.94.135", dst="172.16.10.182")/TCP(sport=57563, dport=80, flags="A", seq=y, ack=x, window=2301)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_7[TCP].payload)
# pkt_8= IP(src="172.16.94.94", dst="172.16.10.182")/TCP(sport=57564, dport=80, flags="S", seq=y, window=29200)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_8[TCP].payload)+1
# pkt_9= IP(src="172.16.10.182", dst="172.16.94.94")/TCP(sport=80, dport=57564, flags="SA", seq=x, ack=y, window=28960)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_9[TCP].payload)+1
# pkt_10= IP(src="172.16.94.94", dst="172.16.10.182")/TCP(sport=57564, dport=80, flags="A", seq=y, ack=x, window=29200)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_10[TCP].payload)
# pkt_11= IP(src="172.16.94.94",  dst="172.16.10.182") / TCP(sport=57564, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="www.tumblr.com", Path="/")
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_11[TCP].payload)
# pkt_12= IP(src="172.16.10.182", dst="172.16.94.94")/TCP(sport=80, dport=57564, flags="A", seq=x, ack=y, window=28960)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_12[TCP].payload)
# pkt_13= IP(src="172.16.10.182",  dst="172.16.94.94") / TCP(sport=80, dport=57564, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "404", Reason_Phrase= "Not Found")
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_13[TCP].payload)
# pkt_14= IP(src="172.16.94.94", dst="172.16.10.182")/TCP(sport=57564, dport=80, flags="A", seq=y, ack=x, window=29200)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_14[TCP].payload)
# pkt_15= IP(src="172.16.94.94",  dst="172.16.10.182") / TCP(sport=57564, dport=80, flags="FA", seq=y, ack=x, window=29200)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_15[TCP].payload)
# pkt_16= IP(src="172.16.10.182", dst="172.16.94.94")/TCP(sport=80, dport=57564, flags="A", seq=x, ack=y+1, window=28960)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_16[TCP].payload)
# pkt_17= IP(src="172.16.10.182", dst="172.16.94.94")/TCP(sport=80, dport=57564, flags="FA", seq=x, ack=y+1, window=28960)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_17[TCP].payload)
# pkt_18= IP(src="172.16.94.94", dst="172.16.10.182")/TCP(sport=57564, dport=80, flags="A", seq=y+1, ack=x+1, window=29200)
# ++++++++++++++++++++++++++++++++++++++++
# 	13. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="DE:F1:23:45:67:89", dst="67:89:AB:CD:EF:12")/scapy.ARP(op=1, pdst="172.16.14.169", psrc="172.16.12.139", hwdst="67:89:AB:CD:EF:12", hwsrc="DE:F1:23:45:67:89")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="67:89:AB:CD:EF:12", dst="DE:F1:23:45:67:89")/scapy.ARP(op=2, psrc="172.16.14.169", hwsrc="67:89:AB:CD:EF:12", hwdst="DE:F1:23:45:67:89", pdst="172.16.12.139")
# 	14. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="10.0.8.120", dst="172.16.34.51")/scapy.ICMP(type=8, id=0xdf86, seq=56322)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="172.16.34.51", dst="10.0.8.120")/scapy.ICMP(type=0, id=0xdf86, seq=56322)
# ++++++++++++++++++++++++++++++++++++++++
# 	15. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="08:15:23:42:56:69", dst="FF:FF:FF:FF:FF:FF")/scapy.ARP(op=1, pdst="10.0.17.94", psrc="10.0.102.22", hwdst="00:00:00:00:00:00", hwsrc="08:15:23:42:56:69")
# time.sleep(random.randint(1,10)/1000000.0)
# rand_MAC= "02:00:00:%02x:%02x:%02x" % (random.randint(0, 255),random.randint(0, 255),random.randint(0, 255))
# pkt_2=scapy.Ether(src=rand_MAC, dst="08:15:23:42:56:69")/scapy.ARP(op=2, psrc="10.0.17.94", hwsrc=rand_MAC, hwdst="08:15:23:42:56:69", pdst="10.0.102.22")
# 	16. Using->  ft:gpt-3.5-turbo-1106:personal:convhttpv4:9Tq7Cjjl
# 		Comand->  x,y = random.sample(range(1, 100), 2)
# pkt_1= IP(src="172.16.144.101", dst="10.0.28.20")/TCP(sport=18560, dport=80, flags="S", seq=y, window=6424)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_1[TCP].payload)+1
# pkt_2= IP(src="10.0.28.20", dst="172.16.144.101")/TCP(sport=80, dport=18560, flags="SA", seq=x, ack=y, window=1250)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_2[TCP].payload)+1
# pkt_3= IP(src="172.16.144.101", dst="10.0.28.20")/TCP(sport=18560, dport=80, flags="A", seq=y, ack=x, window=6424)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_3[TCP].payload)
# pkt_4= IP(src="172.16.144.101",  dst="10.0.28.20") / TCP(sport=18560, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="www.stackoverflow.com", Path="/")
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_4[TCP].payload)
# pkt_5= IP(src="10.0.28.20", dst="172.16.144.101")/TCP(sport=80, dport=18560, flags="A", seq=x, ack=y, window=1250)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_5[TCP].payload)
# pkt_6= IP(src="10.0.28.20",  dst="172.16.144.101") / TCP(sport=80, dport=18560, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "403", Reason_Phrase= "Forbidden")
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_6[TCP].payload)
# pkt_7= IP(src="172.16.144.101", dst="10.0.28.20")/TCP(sport=18560, dport=80, flags="A", seq=y, ack=x, window=6424)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_7[TCP].payload)
# pkt_8= IP(src="172.16.144.101", dst="10.0.28.20")/TCP(sport=18560, dport=80, flags="FA", seq=y, ack=x, window=6424)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_8[TCP].payload)
# pkt_9= IP(src="10.0.28.20", dst="172.16.144.101")/TCP(sport=80, dport=18560, flags="A", seq=x, ack=y+1, window=1250)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_9[TCP].payload)
# pkt_10= IP(src="10.0.28.20", dst="172.16.144.101")/TCP(sport=80, dport=18560, flags="FA", seq=x, ack=y+1, window=1250)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_10[TCP].payload)
# pkt_11= IP(src="172.16.144.101", dst="10.0.28.20")/TCP(sport=18560, dport=80, flags="A", seq=y+1, ack=x+1, window=6424)
# ++++++++++++++++++++++++++++++++++++++++
# 	17. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="BC:DE:F1:23:45:67", dst="56:78:9A:BC:DE:F1")/scapy.ARP(op=1, pdst="172.16.22.206", psrc="172.16.94.41", hwdst="56:78:9A:BC:DE:F1", hwsrc="BC:DE:F1:23:45:67")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="56:78:9A:BC:DE:F1", dst="BC:DE:F1:23:45:67")/scapy.ARP(op=2, psrc="172.16.22.206", hwsrc="56:78:9A:BC:DE:F1", hwdst="BC:DE:F1:23:45:67", pdst="172.16.94.41")
# ++++++++++++++++++++++++++++++++++++++++
# 	18. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="04:2F:3C:4D:5E:6F", dst="67:89:AB:CD:EF:12")/scapy.ARP(op=1, pdst="172.16.249.237", psrc="172.16.47.243", hwdst="67:89:AB:CD:EF:12", hwsrc="04:2F:3C:4D:5E:6F")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="67:89:AB:CD:EF:12", dst="04:2F:3C:4D:5E:6F")/scapy.ARP(op=2, psrc="172.16.249.237", hwsrc="67:89:AB:CD:EF:12", hwdst="04:2F:3C:4D:5E:6F", pdst="172.16.47.243")
# 	19. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="172.16.58.139", dst="172.16.48.113")/scapy.ICMP(type=8, id=0x3ce6, seq=47383)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="172.16.48.113", dst="172.16.58.139")/scapy.ICMP(type=0, id=0x3ce6, seq=47383)
# ++++++++++++++++++++++++++++++++++++++++
# 	20. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="45:67:89:AB:CD:EF", dst="08:15:23:42:56:69")/scapy.ARP(op=1, pdst="10.0.50.175", psrc="10.0.77.242", hwdst="08:15:23:42:56:69", hwsrc="45:67:89:AB:CD:EF")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="08:15:23:42:56:69", dst="45:67:89:AB:CD:EF")/scapy.ARP(op=2, psrc="10.0.50.175", hwsrc="08:15:23:42:56:69", hwdst="45:67:89:AB:CD:EF", pdst="10.0.77.242")
# 	21. Using->  ft:gpt-3.5-turbo-1106:personal:convhttpv4:9Tq7Cjjl
# 		Comand->  x,y = random.sample(range(1, 100), 2)
# pkt_1= IP(src="10.0.127.110", dst="172.16.178.14")/TCP(sport=31339, dport=80, flags="S", seq=y, window=2891)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_1[TCP].payload)+1
# pkt_2= IP(src="172.16.178.14", dst="10.0.127.110")/TCP(sport=80, dport=31339, flags="SA", seq=x, ack=y, window=1778)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_2[TCP].payload)+1
# pkt_3= IP(src="10.0.127.110", dst="172.16.178.14")/TCP(sport=31339, dport=80, flags="A", seq=y, ack=x, window=2891)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_3[TCP].payload)
# pkt_4= IP(src="10.0.127.110",  dst="172.16.178.14") / TCP(sport=31339, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="www.wordpress.com", Path="/")
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_4[TCP].payload)
# pkt_5= IP(src="172.16.178.14", dst="10.0.127.110")/TCP(sport=80, dport=31339, flags="A", seq=x, ack=y, window=1778)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_5[TCP].payload)
# pkt_6= IP(src="172.16.178.14",  dst="10.0.127.110") / TCP(sport=80, dport=31339, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "200", Reason_Phrase= "OK") / "<HTML><BODY><H!>Hello World!</H1></BODY></HTML>"
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_6[TCP].payload)
# pkt_7= IP(src="10.0.127.110", dst="172.16.178.14")/TCP(sport=31339, dport=80, flags="A", seq=y, ack=x, window=2891)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_7[TCP].payload)
# pkt_8= IP(src="10.0.127.110", dst="172.16.178.14")/TCP(sport=31339, dport=80, flags="FA", seq=y, ack=x, window=2891)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_8[TCP].payload)
# pkt_9= IP(src="172.16.178.14", dst="10.0.127.110")/TCP(sport=80, dport=31339, flags="A", seq=x, ack=y+1, window=1778)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_9[TCP].payload)
# pkt_10= IP(src="172.16.178.14", dst="10.0.127.110")/TCP(sport=80, dport=31339, flags="FA", seq=x, ack=y+1, window=1778)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_10[TCP].payload)
# pkt_11= IP(src="10.0.127.110", dst="172.16.178.14")/TCP(sport=31339, dport=80, flags="A", seq=y+1, ack=x+1, window=2891)
# ++++++++++++++++++++++++++++++++++++++++
# 	22. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="F1:23:45:67:89:AB", dst="0A:7A:8B:9C:AD:BE")/scapy.ARP(op=1, pdst="172.16.196.146", psrc="10.0.195.83", hwdst="0A:7A:8B:9C:AD:BE", hwsrc="F1:23:45:67:89:AB")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="0A:7A:8B:9C:AD:BE", dst="F1:23:45:67:89:AB")/scapy.ARP(op=2, psrc="172.16.196.146", hwsrc="0A:7A:8B:9C:AD:BE", hwdst="F1:23:45:67:89:AB", pdst="10.0.195.83")
# 	23. Using->  ft:gpt-3.5-turbo-1106:personal:convdnsv2:9OT57bdn
# 		Comand->  RANDOM_PORT = random.randint(4097, 65530)
# pkt_1 = IP(src="10.0.58.30", dst="10.0.159.208")/UDP(sport=RANDOM_PORT, dport=53)/DNS(id=0xfb1d, qr=0, rd=1, opcode=0, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.twitter.com", qtype="A", qclass="IN"))
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2 = IP(src="10.0.159.208", dst="10.0.153.176")/UDP(sport=53, dport=RANDOM_PORT)/DNS(id=0x0aba, qr=1, opcode=0, ra=1, rcode=0, qdcount=1, ancount=1, nscount=0, arcount=0, qd=DNSQR(qname="www.twitter.com", qtype="A", qclass="IN"), an=DNSRR(rrname="www.twitter.com", type="A", rclass="IN", ttl=255, rdata="10.0.201.243"))
# ++++++++++++++++++++++++++++++++++++++++
# 	24. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="BC:DE:F1:23:45:67", dst="AB:CD:EF:12:34:56")/scapy.ARP(op=1, pdst="10.0.26.120", psrc="10.0.88.106", hwdst="AB:CD:EF:12:34:56", hwsrc="BC:DE:F1:23:45:67")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="AB:CD:EF:12:34:56", dst="BC:DE:F1:23:45:67")/scapy.ARP(op=2, psrc="10.0.26.120", hwsrc="AB:CD:EF:12:34:56", hwdst="BC:DE:F1:23:45:67", pdst="10.0.88.106")
# ++++++++++++++++++++++++++++++++++++++++
# 	25. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="02:0A:0F:1B:2E:3C", dst="F1:23:45:67:89:AB")/scapy.ARP(op=1, pdst="172.16.137.65", psrc="10.0.197.120", hwdst="F1:23:45:67:89:AB", hwsrc="02:0A:0F:1B:2E:3C")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="F1:23:45:67:89:AB", dst="02:0A:0F:1B:2E:3C")/scapy.ARP(op=2, psrc="172.16.137.65", hwsrc="F1:23:45:67:89:AB", hwdst="02:0A:0F:1B:2E:3C", pdst="10.0.197.120")
# 	26. Using->  ft:gpt-3.5-turbo-1106:personal:convhttpv4:9Tq7Cjjl
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 45
#      42     packets = generate_packets(summaries)
#      44 elif functioning =="Conversations":
# ---> 45     packets = generate_Conversations(summaries)
#      47 print(packets)
#      49 print("\nGenerated {} packets.\nWriting them to {} ...".format(
#      50         len(packets),
#      51         pcap_saved))
#
# Cell In[13], line 57, in generate_Conversations(summaries)
#      54 commands = responses[-1].completion.choices[0].message.content[1:]
#      56 ldict = {}
# ---> 57 exec(commands,globals(),ldict)
#      59 if protocol != "HTTP":
#      60     packets.append([ldict['pkt_1'], ldict['pkt_2']])
#
# File <string>:19
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'tuple'

# %%
write_pcap(packets, pcap_saved)
