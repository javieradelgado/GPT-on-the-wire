# %% [markdown]
# # MOE architecture
# ----
#
# This notebook will have the basics of a AI MOE system where each expert is specilized in a single protocol and is able to create single packages of that protocol.
#
# <center><img src="https://www.datocms-assets.com/96965/1695407447-image1.png">

# %% [markdown]
# #### Imports

# %%
import os
os.environ['OPENAI_API_KEY'] = ''

import openai
from openai import OpenAI
client = OpenAI()

import random
import re
import pickle
import scapy
import toml
import ipaddress

from scapy.all import *
from scapy.utils import RawPcapReader, wrpcap
import scapy.all as scapy
from scapy.layers.l2 import Ether, ARP
from scapy.layers.inet import IP, ICMP
from scapy.layers.http import *
# Out:
# C:\Users\adayd\anaconda3\envs\PAC-GPT\Lib\site-packages\scapy\layers\ipsec.py:469: CryptographyDeprecationWarning: Blowfish has been deprecated
#   cipher=algorithms.Blowfish,
# C:\Users\adayd\anaconda3\envs\PAC-GPT\Lib\site-packages\scapy\layers\ipsec.py:483: CryptographyDeprecationWarning: CAST5 has been deprecated
#   cipher=algorithms.CAST5,

# %% [markdown]
# #### Definitions

# %%
ip_file = "../../scripts/sample_input/ip_file.toml"
mac_file = "../../scripts/sample_input/mac_file.txt"
resource_file = "../../scripts/sample_input/resource_file.txt"

functioning ="Conversations"

number_of_creations = 15
protocols = ["icmp", "arp", "dns", "http"]
HTTPCodes = [200, 307, 403, 404]
HTTPPhrases = ["OK", "Temporary Redirect", "Forbidden", "Not Found"]


Models_file = 'Models.jsonl'
pkl_saved = "../../data/MOE/pickle/MOE_Conversations_Fine_Tuned.pkl"
pcap_saved = "../../data/MOE/pcap/MOE_Conversations_generated_3_5_turbo-instruct_conv.pcap"

system_message = 'You are a new generation traffic generator. \
You are specilized in the {} protocol and {} generation using python and scapy. \
You are especially attentive to variables and different types of traffic.'

# %% [markdown]
# ## Step 1: Important functions definition

# %% [markdown]
# #### load_toml:
# Lee y procesa un paquete toml definido por el usuario. Este paquete Toml es donde están las IPs de diferentes redes, un equipo victima y otro atacante.

# %%
def load_toml(ip_file):
    network_ips = []
    victim_ip = ""
    attacker_ip = ""
    with open(ip_file, "r") as f:
        data = toml.load(f)
        for ip_desc in data['network']['ip']:
            # Convierte cada elemento en un objeto de red IP usando la función ipaddress.ip_network
            # Elimina los espacios en blanco al principio y al final del elemento con el método strip
            # Usa el método hosts para obtener una lista de los hosts de la red
            # Añade los hosts a la lista network_ips con el método extend
            network_ips.extend(ipaddress.ip_network(ip_desc.strip()).hosts())
        victim_ip = ipaddress.ip_network(data['victim']['ip'].strip()).hosts()
        attacker_ip = ipaddress.ip_network(
            data['attacker']['ip'].strip()).hosts()

    return network_ips, victim_ip, attacker_ip

# %%
def load_txt(file):
    with open(file,"r") as f:
        return f.read().splitlines()

# %% [markdown]
# #### generate_packet_summaries:
#
# Esto es un generador automático de resumenes de paquetes basado en la aleatoriedad de la función random.choice()
# Solo es capaz de generar resuemenes de tráfico ICMP y DNS, en teoría los elige de los protocolos en la lista protocols pero solo se pueden generar esos 2
# Para generar resumenes selecciona aleatoriamente 2 ips de una lista de IPs que se le pasa
# Tambien elige aleatoriamente el resto de variables de los paquetes como son la id, sqe, longitud
# Por cada paquete generado se aumenta en 2 el ctr
# EL generador se para cuando se cumple la condición del ctr, esta condición depende de la variable n que se le pase

# %%
def generate_packet_summaries(ip_list, n, protocols, mac_list=None, resource_list=None):
    summaries = []
    ctr = 0
    while ctr < math.ceil(n/5)*5:
        proto = random.choice(protocols)
        if proto == "icmp":
            ip1, ip2 = random.choices(ip_list, k=2)
            random_id, random_seq = random.randint(
                0, 65535), random.randint(0, 65535)
            random_length = random.choice([76, 100])
            summaries.append(
                "{} → {} ICMP {} (ping) request id={:#06x}, seq={}".format(
                    ip1, ip2, random_length, random_id, random_seq))
            summaries.append(
                "{} → {} ICMP {} (ping) reply id={:#06x}, seq={}".format(
                    ip2, ip1, random_length, random_id, random_seq))
            ctr += 2
        elif proto == "arp":
            mac1, mac2 = random.choices(mac_list, k=2)
            if mac2 == "FF:FF:FF:FF:FF:FF":
                mac3 = random.choices(mac_list, k=2)
            else:
                if  random.choice([0, 10]) < 5:
                    mac3 = mac2
                else:
                    mac3 =  random.choices(mac_list, k=1)
                    while mac3 == "FF:FF:FF:FF:FF:FF" or mac3 == mac1:
                        mac3 =  random.choices(ordest_list, k=1)
            
            ip1, ip2 = random.choices(ip_list, k=2)
            
            random_length = random.choice([76, 100])
            summaries.append(
                "{}     {}     ARP      {}     Who has {}? Tell {}".format(
                    mac1, mac2, random_length, ip1, ip2))
            summaries.append(
                "{}     {}     ARP      {}     {} is at {}".format(
                    mac3, mac1, random_length, ip1, mac3))
            ctr += 2
    return summaries

# %% [markdown]
# #### generate_conversation_summaries:
#
# Esto es un generador automático de resumenes de conversaciones basado en la aleatoriedad de la función random.choice()
# Solo es capaz de generar resuemenes de tráfico ICMP, ARP y DNS, en teoría los elige de los protocolos en la lista protocols pero solo se pueden generar esos 3.
# Para generar resumenes seleccionan aleatoriamente las ips de una lista de IPs que se le pasa.
# Tambien elige aleatoriamente el resto de variables de los paquetes como son la id, sqe, longitud.
# Por cada paquete generado se aumenta en 2 el ctr.
# EL generador se para cuando se cumple la condición del ctr, esta condición depende de la variable n que se le pase.

# %%
def generate_conversation_summaries(ip_list, n, protocols, mac_list=None, resource_list=None):
    summaries = []
    ctr = 0
    while ctr < n:
        proto = random.choice(protocols)
        
        if proto == "icmp":
            ip1, ip2 = random.choices(ip_list, k=2)
            random_id, random_seq = random.randint(
                0, 65535), random.randint(0, 65535)
            random_type = random.choice(["Echo", "Timestamp"])
            summaries.append(
                "Source: IP={} // Destination: IP={} // Others: id={:#06x} seq= {} type={}".format(
                    ip1, ip2, random_id, random_seq, random_type))
            ctr += 1
        elif proto == "arp":
            mac1, mac2 = random.choices(mac_list, k=2)
            
            while mac1 == "FF:FF:FF:FF:FF:FF":
                mac1 = random.choices(mac_list, k=1)
                
            ip1, ip2 = random.choices(ip_list, k=2)
            
            summaries.append(
                "Source: MAC={}, IP={} // Destination: MAC={} // Wanted: IP= {}".format(
                    mac1, ip1, mac2, ip2))
            ctr += 1
            
        elif proto == "dns":
            
            ip1, ip2, ip3 = random.choices(ip_list, k=3)
            random_id = random.randint(0, 65535)
            random_resource = random.choices(resource_list, k=1)
            
            summaries.append(
            "Source: IP= {} // Destination: IP= {} // Others: {:#06x} , resource= {} , response = {}".format(
                    ip1, ip2, random_id, random_resource, ip3))
            
            ctr += 1
            
        elif proto == "http":
            
            ip1, ip2= random.choices(ip_list, k=2)
            port1 = random.randint(1025, 65535)
            window1, window2 = random.randint(200, 6535), random.randint(200, 6535)
            random_resource = random.choices(resource_list, k=1)
            index = random.randint(0, 3)
            code = HTTPCodes[index]
            ReasonPhrase = HTTPPhrases[index]
            
            summaries.append(
            "Source: IP={}, port={}, Window: {} // Destination: IP={}, port=80, Window: {} // Others: Host={}, Path="", Code={}, Reason_Phrase= {}".format(
                    ip1, port1, window1, ip2, window2, random_resource, code, ReasonPhrase))
            
            
            ctr += 1
            
    return summaries

# %% [markdown]
# #### generate_ping_flood_summaries
# Al contrario que el generador anterior, este sirve para generar un ataque de ping flood a una victima en concreto
# También basado en probabilidad, si es True, se envía trafico maligno a la victima desde el atacante, si no, tráfico normal de la red con 2 equipos aleatorios
# Si es tráfico normal, se genera tanto la petición como la respuesta

# %%
def generate_ping_flood_summaries(ip_list, n, victim_ip, attacker_ip):
    summaries = []
    ctr = 0
    while ctr < math.ceil(n/5)*5:
        malicious = random.choices([True, False], weights=[0.7, 0.3], k=1)
        if malicious[0]: #Si es True
            random_id, random_seq = random.randint(
                0, 65535), random.randint(0, 65535)
            random_length = random.choice([76, 100])
            summaries.append(
                "{} → {} ICMP {} (ping) request id={:#06x}, seq={}".format(
                    attacker_ip, victim_ip, random_length, random_id, random_seq))
            ctr += 1
        else:
            ip1, ip2 = random.choices(ip_list, k=2)
            random_id, random_seq = random.randint(
                0, 65535), random.randint(0, 65535)
            random_length = random.choice([76, 100])
            summaries.append(
                "{} → {} ICMP {} (ping) request id={:#06x}, seq={}".format(
                    ip1, ip2, random_length, random_id, random_seq))
            summaries.append(
                "{} → {} ICMP {} (ping) reply id={:#06x}, seq={}".format(
                    ip2, ip1, random_length, random_id, random_seq))
            ctr += 2
    return summaries

# %% [markdown]
# #### generate_packets
#
# Se envian resumenes de paquetes de 5 en 5 al modelo, para ello se usa la variable ctr
# Se obtiene la lista de comandos de Scapy y antes de ejecutarla se añade una instrucción para anexar los paquetes creados a una lista grande npackets
# luego se ejecutan todas las instrcciones y se devuelven los paquetes

# %%
def generate_packets(summaries):
    ctr = 1
    packets = []
    prompt = ""
    for summary in summaries:
        prompt += summary + "\n"
        protocol = obtain_Packet_protocol(summary)
    
        
        if protocol == "ICMP":
            messages=[{"role": "system", "content": system_message.format("ICMP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Packets"]["Specific"]["ICMP"])
            completion = client.chat.completions.create(
            model=Models_list[functioning]["Specific"]["ICMP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
        
        elif protocol == "ARP":
            messages=[{"role": "system", "content": system_message.format("ARP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Packets"]["Specific"]["ARP"])
            completion = client.chat.completions.create(
            model=Models_list[functioning]["Specific"]["ARP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
        
        elif protocol == "DNS":
            messages=[{"role": "system", "content": system_message.format("DNS", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Packets"]["Specific"]["DNS"])
            completion = client.chat.completions.create(
            model=Models_list[functioning]["Specific"]["DNS"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
        
        elif protocol == "HTTP":
            messages=[{"role": "system", "content": system_message.format("HTTP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Packets"]["Specific"]["HTTP"])
            completion = client.chat.completions.create(
            model=Models_list[functioning]["Specific"]["HTTP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
        
        
        responses.append(response(messages, completion))
        pickle.dump(responses, open(pkl_saved, "wb" ) )
        
        print("\t\t" + "Comand->  " + str(responses[-1].completion.choices[0].message.content))
        exec("packets.append(" + str(responses[-1].completion.choices[0].message.content + ")"))
        ctr += 1
    return packets

# %%
def obtain_Packet_protocol(summary):
    if "ICMP" in summary:
        return "ICMP"
    elif "ARP" in summary:
        return "ARP"
    elif "DNS" in summary:
        return "DNS"
    elif "HTTP" in summary:
        return "HTTP"
    else:
        raise TypeError("Unsupported protocol.")

# %%
paquetes = []
def exec_commands(commands):
    print(commands)
    exec(commands)
        
    if protocol != "HTTP":
        pkt_1.show()
        paquetes.append([pkt_1, pkt_2])
        del pkt_1, pkt_2
    else:
        pkt_1.show()
        paquetes.append([pkt_1, pkt_2, pkt_3, pkt_4, pkt_5, pkt_6, pkt_7, pkt_8, pkt_9, pkt_10, pkt_11])
        del pkt_1, pkt_2, pkt_3, pkt_4, pkt_5, pkt_6, pkt_7, pkt_8, pkt_9, pkt_10, pkt_11
    
    return paquetes

# %%
def generate_Conversations(summaries):
    
    ctr= 1
    packets = []
    prompt = ""
    for summary in summaries:
        prompt += summary + "\n"
        protocol = obtain_Conversation_protocol(summary)
        
        if protocol == "ICMP":
            messages=[{"role": "system", "content": system_message.format("ICMP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Conversations"]["Specific"]["ICMP"])
            completion = client.chat.completions.create(
            model=Models_list["Conversations"]["Specific"]["ICMP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
            
        elif protocol == "ARP":
            messages=[{"role": "system", "content": system_message.format("ARP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Conversations"]["Specific"]["ARP"])
            completion = client.chat.completions.create(
            model=Models_list["Conversations"]["Specific"]["ARP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)

        elif protocol == "DNS":
            messages=[{"role": "system", "content": system_message.format("DNS", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Conversations"]["Specific"]["DNS"])
            completion = client.chat.completions.create(
            model=Models_list["Conversations"]["Specific"]["DNS"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
        
        elif protocol == "HTTP":
            messages=[{"role": "system", "content": system_message.format("HTTP", functioning)},
            {"role": "user", "content": summary}]
            print("\t" + str(ctr)+". Using->  " + Models_list["Conversations"]["Specific"]["HTTP"])
            completion = client.chat.completions.create(
            model=Models_list["Conversations"]["Specific"]["HTTP"], 
            messages=messages,
            max_tokens=2600,
            temperature=0.1)
            
        
        responses.append(response(messages, completion))
        pickle.dump(responses, open(pkl_saved, "wb" ) )
        commands = responses[-1].completion.choices[0].message.content[1:]
        
        ldict = {}
        exec(commands,globals(),ldict)
        
        if protocol != "HTTP":
            packets.append([ldict['pkt_1'], ldict['pkt_2']])
            del ldict
        else:
            packets.append([ldict['pkt_1'], ldict['pkt_2'], ldict['pkt_3'], ldict['pkt_4'], ldict['pkt_5'], ldict['pkt_6'], ldict['pkt_7'], ldict['pkt_8'], ldict['pkt_9'], ldict['pkt_10'], ldict['pkt_11']])
            del ldict
        
        print("\t\t" + "Comand->  " + commands)
        
        ctr += 1
    return packets

# %%
def obtain_Conversation_protocol(summary):
    if "seq=" in summary:
        return "ICMP"
    elif "MAC=" in summary:
        return "ARP"
    elif "response" in summary:
        return "DNS"
    elif "Window:" in summary:
        return "HTTP"
    else:
        raise TypeError("Unsupported protocol.")

# %%
def write_pcap(packets, pcap_saved):
    for packet in packets:
        with open(pcap_saved, "ba+") as f:
            wrpcap(f, packet, append=True)

# %%
class response():
    "Stores name and place pairs"
    def __init__(self, name, place):
        self.prompt_summary = name
        self.completion = place

try:
    responses = pickle.load( open(pkl_saved, "rb" ))
except:
    responses = []

print("Number of previous responses: " + str(len(responses)))
# Out:
# Number of previous responses: 0

# %%
with open(Models_file, 'r') as json_file:
    Models_list = json.load(json_file)

print("\n---------------------------------------------------------")
print("                 Availiable PACKET models                  ")
print("---------------------------------------------------------\n")
for key, value in Models_list["Packets"]["Specific"].items():
    print( "\t" + key + " -> " + value)

print("\n---------------------------------------------------------")
print("             Availiable CONVERSATIONS models               ")
print("---------------------------------------------------------\n")
for key, value in Models_list["Conversations"]["Specific"].items():
    print( "\t" + key + " -> " + value)

print("\n---------------------------------------------------------")
print("                    Packet generation                    ")
print("---------------------------------------------------------\n")

network_ips, victim_ip, attacker_ip = load_toml(ip_file)
mac_list = load_txt(mac_file)
resource_list = load_txt(resource_file)

if functioning =="Packets":
    summaries = generate_packet_summaries(
            network_ips, n=number_of_creations, protocols=protocols, mac_list=mac_list, resource_list=resource_list)
elif functioning =="Conversations":
    summaries = generate_conversation_summaries(
            network_ips, n=number_of_creations, protocols=protocols, mac_list=mac_list, resource_list=resource_list)

print("Generated {} summaries:\n".format(len(summaries)))
for index in range(len(summaries)):
    print("\t" + str(index+1)+". " + summaries[index])

print("\n---------------------------------------------------------")
print("        Using OpenAI API to generate packets...          ")
print("---------------------------------------------------------\n")

packets =[]

if functioning =="Packets":
    packets = generate_packets(summaries)

elif functioning =="Conversations":
    packets = generate_Conversations(summaries)

print(packets)

print("\nGenerated {} packets.\nWriting them to {} ...".format(
        len(packets),
        pcap_saved))

write_pcap(packets, pcap_saved)
print("Done!")
# Out:
# ---------------------------------------------------------
#                  Availiable PACKET models
# ---------------------------------------------------------
#
# 	ICMPv1 -> ft:gpt-3.5-turbo-0125:personal:icmpv1:9ELvoktd
# 	ICMPv2 -> ft:gpt-3.5-turbo-1106:personal:icmpv2:9F2iiDZa
# 	DNS ->
# 	ARP -> ft:gpt-3.5-turbo-1106:personal:arpv1:9FLIvsUk
# 	ARPv2 -> ft:gpt-3.5-turbo-1106:personal:arpv2:9FPXrE3X
# 	HTTP ->
#
# ---------------------------------------------------------
#              Availiable CONVERSATIONS models
# ---------------------------------------------------------
#
# 	ICMP -> ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 	DNS -> ft:gpt-3.5-turbo-1106:personal:convdnsv2:9OT57bdn
# 	ARP -> ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 	HTTP -> ft:gpt-3.5-turbo-1106:personal:convhttpv1:9OrZ0MUz
#
# ---------------------------------------------------------
#                     Packet generation
# ---------------------------------------------------------
#
# Generated 15 summaries:
#
# 	1. Source: IP=10.0.72.84 // Destination: IP=10.0.32.61 // Others: id=0x7cc8 seq= 45110 type=Echo
# 	2. Source: IP=10.0.206.116, port=4874, Window: 4232 // Destination: IP=172.16.159.69, port=80, Window: 1985 // Others: Host=['www.adobe.com'], Path=, Code=403, Reason_Phrase= Forbidden
# 	3. Source: IP= 10.0.100.73 // Destination: IP= 10.0.31.39 // Others: 0x5de6 , resource= ['www.xvideos.com'] , response = 172.16.144.9
# 	4. Source: IP=10.0.194.105 // Destination: IP=172.16.138.57 // Others: id=0xb48c seq= 57849 type=Timestamp
# 	5. Source: IP=172.16.241.164, port=60713, Window: 2105 // Destination: IP=10.0.89.36, port=80, Window: 4225 // Others: Host=['www.xvideos.com'], Path=, Code=200, Reason_Phrase= OK
# 	6. Source: IP=10.0.111.222 // Destination: IP=172.16.8.214 // Others: id=0x93a0 seq= 19746 type=Echo
# 	7. Source: IP=192.168.1.136 // Destination: IP=172.16.129.196 // Others: id=0xaa1c seq= 43580 type=Echo
# 	8. Source: IP= 172.16.252.235 // Destination: IP= 10.0.111.243 // Others: 0x4ff6 , resource= ['www.etsy.com'] , response = 10.0.80.212
# 	9. Source: MAC=02:0A:0F:1B:2E:3C, IP=172.16.61.53 // Destination: MAC=0A:7A:8B:9C:AD:BE // Wanted: IP= 172.16.43.24
# 	10. Source: IP=172.16.16.195 // Destination: IP=172.16.211.121 // Others: id=0x82b2 seq= 59658 type=Echo
# 	11. Source: IP=10.0.28.127 // Destination: IP=10.0.186.254 // Others: id=0xe58e seq= 53962 type=Echo
# 	12. Source: IP=10.0.196.115 // Destination: IP=172.16.1.203 // Others: id=0x6b1d seq= 47504 type=Echo
# 	13. Source: IP= 172.16.1.53 // Destination: IP= 172.16.15.18 // Others: 0xe392 , resource= ['www.xvideos.com'] , response = 10.0.85.129
# 	14. Source: IP=172.16.223.220 // Destination: IP=10.0.46.240 // Others: id=0xfd62 seq= 37291 type=Echo
# 	15. Source: IP= 172.16.142.59 // Destination: IP= 172.16.18.10 // Others: 0xfd08 , resource= ['www.qq.com'] , response = 10.0.13.90
#
# ---------------------------------------------------------
#         Using OpenAI API to generate packets...
# ---------------------------------------------------------
#
# 	1. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="10.0.72.84", dst="10.0.32.61")/scapy.ICMP(type=8, id=0x7cc8, seq=45110)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="10.0.32.61", dst="10.0.72.84")/scapy.ICMP(type=0, id=0x7cc8, seq=45110)
# 	2. Using->  ft:gpt-3.5-turbo-1106:personal:convhttpv1:9OrZ0MUz
# 		Comand->  x,y = random.sample(range(1, 100), 2)
# pkt_1= IP(src="10.0.206.116", dst="172.16.159.69")/TCP(sport=4874, dport=80, flags="S", seq=y, window=4232)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_1[TCP].payload)+1
# pkt_2= IP(src="172.16.159.69", dst="10.0.206.116")/TCP(sport=80, dport=4874, flags="SA", seq=x, ack=y, window=1985)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_2[TCP].payload)+1
# pkt_3= IP(src="10.0.206.116", dst="172.16.159.69")/TCP(sport=4874, dport=80, flags="A", seq=y, ack=x, window=4232)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_3[TCP].payload)
# pkt_4= IP(src="10.0.206.116", dst="172.16.159.69")/TCP(sport=4874, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="www.adobe.com", Path="/")
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_4[TCP].payload)
# pkt_5= IP(src="172.16.159.69", dst="10.0.206.116")/TCP(sport=80, dport=4874, flags="A", seq=x, ack=y, window=1985)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_5[TCP].payload)
# pkt_6= IP(src="172.16.159.69", dst="10.0.206.116")/TCP(sport=80, dport=4874, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "403", Reason_Phrase= "Forbidden")
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_6[TCP].payload)
# pkt_7= IP(src="10.0.206.116", dst="172.16.159.69")/TCP(sport=4874, dport=80, flags="A", seq=y, ack=x, window=4232)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_7[TCP].payload)
# pkt_8= IP(src="10.0.206.116", dst="172.16.159.69")/TCP(sport=4874, dport=80, flags="FA", seq=y, ack=x, window=4232)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_8[TCP].payload)
# pkt_9= IP(src="172.16.159.69", dst="10.0.206.116")/TCP(sport=80, dport=4874, flags="A", seq=x, ack=y, window=1985)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_9[TCP].payload)
# pkt_10= IP(src="172.16.159.69", dst="10.0.206.116")/TCP(sport=80, dport=4874, flags="FA", seq=x, ack=y, window=1985)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_10[TCP].payload)
# pkt_11= IP(src="10.0.206.116", dst="172.16.159.69")/TCP(sport=4874, dport=80, flags="A", seq=y, ack=x, window=4232)
# 	3. Using->  ft:gpt-3.5-turbo-1106:personal:convdnsv2:9OT57bdn
# 		Comand->  RANDOM_PORT = random.randint(4097, 65530)
# pkt_1 = IP(src="10.0.100.73", dst="10.0.31.39")/UDP(sport=RANDOM_PORT, dport=53)/DNS(id=0x5de6, qr=0, rd=1, opcode=0, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.xvideos.com", qtype="A", qclass="IN"))
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2 = IP(src="10.0.31.39", dst="172.16.144.9")/UDP(sport=53, dport=53)/DNS(id=0x0aba, qr=0, opcode=0, rd=1, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.xvideos.com", qtype="A", qclass="IN"))
# 	4. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="10.0.194.105", dst="172.16.138.57")/scapy.ICMP(type=13, id=0xb48c, seq=57849)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="172.16.138.57", dst="10.0.194.105")/scapy.ICMP(type=14, id=0xb48c, seq=57849)
# 	5. Using->  ft:gpt-3.5-turbo-1106:personal:convhttpv1:9OrZ0MUz
# 		Comand->  x,y = random.sample(range(1, 100), 2)
# pkt_1= IP(src="172.16.241.164", dst="10.0.89.36")/TCP(sport=60713, dport=80, flags="S", seq=y, window=2105)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_1[TCP].payload)+1
# pkt_2= IP(src="10.0.89.36", dst="172.16.241.164")/TCP(sport=80, dport=60713, flags="SA", seq=x, ack=y, window=4225)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_2[TCP].payload)+1
# pkt_3= IP(src="172.16.241.164", dst="10.0.89.36")/TCP(sport=60713, dport=80, flags="A", seq=y, ack=x, window=2105)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_3[TCP].payload)
# pkt_4= IP(src="10.0.89.36", dst="172.16.241.164")/TCP(sport=80, dport=60713, flags="A", seq=x, ack=y, window=4225)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_4[TCP].payload)
# pkt_5= IP(src="10.0.89.36", dst="172.16.241.164")/TCP(sport=80, dport=60713, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="www.xvideos.com", Path="/")
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_5[TCP].payload)
# pkt_6= IP(src="172.16.241.164", dst="10.0.89.36")/TCP(sport=60713, dport=80, flags="A", seq=y, ack=x, window=2105)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_6[TCP].payload)
# pkt_7= IP(src="172.16.241.164", dst="10.0.89.36")/TCP(sport=60713, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "200", Reason_Phrase= "OK") / "<HTML><BODY><H1>Welcome to xvideos!</H1></BODY></HTML>"
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_7[TCP].payload)
# pkt_8= IP(src="10.0.89.36", dst="172.16.241.164")/TCP(sport=80, dport=60713, flags="A", seq=x, ack=y, window=4225)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_8[TCP].payload)
# pkt_9= IP(src="10.0.89.36", dst="172.16.241.164")/TCP(sport=80, dport=60713, flags="FA", seq=x, ack=y, window=4225)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_9[TCP].payload)
# pkt_10= IP(src="172.16.241.164", dst="10.0.89.36")/TCP(sport=60713, dport=80, flags="A", seq=y, ack=x, window=2105)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_10[TCP].payload)
# pkt_11= IP(src="172.16.241.164", dst="10.0.89.36")/TCP(sport=60713, dport=80, flags="FA", seq=y, ack=x, window=2105)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_11[TCP].payload)
# pkt_12= IP(src="10.0.89.36", dst="172.16.241.164")/TCP(sport=80, dport=60713, flags="A", seq=x, ack=y, window=4225)
# 	6. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="10.0.111.222", dst="172.16.8.214")/scapy.ICMP(type=8, id=0x93a0, seq=19746)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="172.16.8.214", dst="10.0.111.222")/scapy.ICMP(type=0, id=0x93a0, seq=19746)
# 	7. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="192.168.1.136", dst="172.16.129.196")/scapy.ICMP(type=8, id=0xaa1c, seq=43580)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="172.16.129.196", dst="192.168.1.136")/scapy.ICMP(type=0, id=0xaa1c, seq=43580)
# 	8. Using->  ft:gpt-3.5-turbo-1106:personal:convdnsv2:9OT57bdn
# 		Comand->  RANDOM_PORT = random.randint(4097, 65530)
# pkt_1 = IP(src="172.16.252.235", dst="10.0.111.243")/UDP(sport=RANDOM_PORT, dport=53)/DNS(id=0x4ff6, qr=0, rd=1, opcode=0, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.etsy.com", qtype="A", qclass="IN"))
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2 = IP(src="10.0.111.243", dst="10.0.80.212")/UDP(sport=53, dport=1234)/DNS(id=0x0aba, qr=0, opcode=0, rd=1, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.etsy.com", qtype="A", qclass="IN"))
# 	9. Using->  ft:gpt-3.5-turbo-1106:personal:convarpv2:9OUMMFtw
# 		Comand->  pkt_1=scapy.Ether(src="02:0A:0F:1B:2E:3C", dst="0A:7A:8B:9C:AD:BE")/scapy.ARP(op=1, pdst="172.16.43.24", psrc="172.16.61.53", hwdst="0A:7A:8B:9C:AD:BE", hwsrc="02:0A:0F:1B:2E:3C")
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.Ether(src="0A:7A:8B:9C:AD:BE", dst="02:0A:0F:1B:2E:3C")/scapy.ARP(op=2, psrc="172.16.43.24", hwsrc="0A:7A:8B:9C:AD:BE", hwdst="02:0A:0F:1B:2E:3C", pdst="172.16.61.53")
# 	10. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="172.16.16.195", dst="172.16.211.121")/scapy.ICMP(type=8, id=0x82b2, seq=59658)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="172.16.211.121", dst="172.16.16.195")/scapy.ICMP(type=0, id=0x82b2, seq=59658)
# 	11. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="10.0.28.127", dst="10.0.186.254")/scapy.ICMP(type=8, id=0xe58e, seq=53962)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="10.0.186.254", dst="10.0.28.127")/scapy.ICMP(type=0, id=0xe58e, seq=53962)
# 	12. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="10.0.196.115", dst="172.16.1.203")/scapy.ICMP(type=8, id=0x6b1d, seq=47504)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="172.16.1.203", dst="10.0.196.115")/scapy.ICMP(type=0, id=0x6b1d, seq=47504)
# 	13. Using->  ft:gpt-3.5-turbo-1106:personal:convdnsv2:9OT57bdn
# 		Comand->  RANDOM_PORT = random.randint(4097, 65530)
# pkt_1 = IP(src="172.16.1.53", dst="172.16.15.18")/UDP(sport=RANDOM_PORT, dport=53)/DNS(id=0xe392, qr=0, rd=1, opcode=0, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.xvideos.com", qtype="A", qclass="IN"))
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2 = IP(src="172.16.15.18", dst="10.0.85.129")/UDP(sport=53, dport=50001)/DNS(id=0x0aba, qr=1, opcode=0, ra=1, rcode=0, qdcount=1, ancount=1, nscount=0, arcount=0, qd=DNSQR(qname="www.xvideos.com", qtype="A", qclass="IN"), an=DNSRR(rrname="www.xvideos.com", type="A", rclass="IN", ttl=255, rdata="192.168.1.10"))
# 	14. Using->  ft:gpt-3.5-turbo-1106:personal:convicmpv2:9OTQhQhP
# 		Comand->  pkt_1=scapy.IP(src="172.16.223.220", dst="10.0.46.240")/scapy.ICMP(type=8, id=0xfd62, seq=37291)
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2=scapy.IP(src="10.0.46.240", dst="172.16.223.220")/scapy.ICMP(type=0, id=0xfd62, seq=37291)
# 	15. Using->  ft:gpt-3.5-turbo-1106:personal:convdnsv2:9OT57bdn
# 		Comand->  RANDOM_PORT = random.randint(4097, 65530)
# pkt_1 = IP(src="172.16.142.59", dst="172.16.18.10")/UDP(sport=RANDOM_PORT, dport=53)/DNS(id=0xfd08, qr=0, rd=1, opcode=0, qdcount=1, ancount=0, nscount=0, arcount=0, qd=DNSQR(qname="www.qq.com", qtype="A", qclass="IN"))
# time.sleep(abs(random.gauss(0, 0.03)))
# pkt_2 = IP(src="172.16.18.10", dst="10.0.13.90")/UDP(sport=53, dport=RANDOM_PORT)/DNS(id=0x0aba, qr=1, opcode=0, ra=1, rcode=0, qdcount=1, ancount=1, nscount=0, arcount=0, qd=DNSQR(qname="www.qq.com", qtype="A", qclass="IN"), an=DNSRR(rrname="www.qq.com", type="A", rclass="IN", ttl=255, rdata="10.0.5.196"))
# [[<IP  frag=0 proto=icmp src=10.0.72.84 dst=10.0.32.61 |<ICMP  type=echo-request id=0x7cc8 seq=0xb036 |>>, <IP  frag=0 proto=icmp src=10.0.32.61 dst=10.0.72.84 |<ICMP  type=echo-reply id=0x7cc8 seq=0xb036 |>>], [<IP  frag=0 proto=tcp src=10.0.206.116 dst=172.16.159.69 |<TCP  sport=4874 dport=http seq=92 flags=S window=4232 |>>, <IP  frag=0 proto=tcp src=172.16.159.69 dst=10.0.206.116 |<TCP  sport=http dport=4874 seq=77 ack=93 flags=SA window=1985 |>>, <IP  frag=0 proto=tcp src=10.0.206.116 dst=172.16.159.69 |<TCP  sport=4874 dport=http seq=93 ack=78 flags=A window=4232 |>>, <IP  frag=0 proto=tcp src=10.0.206.116 dst=172.16.159.69 |<TCP  sport=4874 dport=http seq=93 ack=78 flags=PA window=8192 |<HTTP  |<HTTPRequest  Method='GET' Path='/' Http_Version='HTTP/1.1' Host='www.adobe.com' |>>>>, <IP  frag=0 proto=tcp src=172.16.159.69 dst=10.0.206.116 |<TCP  sport=http dport=4874 seq=78 ack=132 flags=A window=1985 |>>, <IP  frag=0 proto=tcp src=172.16.159.69 dst=10.0.206.116 |<TCP  sport=http dport=4874 seq=78 ack=132 flags=PA window=8192 |<HTTP  |<HTTPResponse  Http_Version='HTTP/1.1' Status_Code='403' Reason_Phrase='Forbidden' |>>>>, <IP  frag=0 proto=tcp src=10.0.206.116 dst=172.16.159.69 |<TCP  sport=4874 dport=http seq=132 ack=104 flags=A window=4232 |>>, <IP  frag=0 proto=tcp src=10.0.206.116 dst=172.16.159.69 |<TCP  sport=4874 dport=http seq=132 ack=104 flags=FA window=4232 |>>, <IP  frag=0 proto=tcp src=172.16.159.69 dst=10.0.206.116 |<TCP  sport=http dport=4874 seq=104 ack=132 flags=A window=1985 |>>, <IP  frag=0 proto=tcp src=172.16.159.69 dst=10.0.206.116 |<TCP  sport=http dport=4874 seq=104 ack=132 flags=FA window=1985 |>>, <IP  frag=0 proto=tcp src=10.0.206.116 dst=172.16.159.69 |<TCP  sport=4874 dport=http seq=132 ack=104 flags=A window=4232 |>>], [<IP  frag=0 proto=udp src=10.0.100.73 dst=10.0.31.39 |<UDP  sport=6150 dport=domain |<DNS  id=24038 qr=0 opcode=QUERY rd=1 qdcount=1 ancount=0 nscount=0 arcount=0 qd=<DNSQR  qname='www.xvideos.com' qtype=A qclass=IN |> |>>>, <IP  frag=0 proto=udp src=10.0.31.39 dst=172.16.144.9 |<UDP  sport=domain dport=domain |<DNS  id=2746 qr=0 opcode=QUERY rd=1 qdcount=1 ancount=0 nscount=0 arcount=0 qd=<DNSQR  qname='www.xvideos.com' qtype=A qclass=IN |> |>>>], [<IP  frag=0 proto=icmp src=10.0.194.105 dst=172.16.138.57 |<ICMP  type=timestamp-request id=0xb48c seq=0xe1f9 |>>, <IP  frag=0 proto=icmp src=172.16.138.57 dst=10.0.194.105 |<ICMP  type=timestamp-reply id=0xb48c seq=0xe1f9 |>>], [<IP  frag=0 proto=tcp src=172.16.241.164 dst=10.0.89.36 |<TCP  sport=60713 dport=http seq=19 flags=S window=2105 |>>, <IP  frag=0 proto=tcp src=10.0.89.36 dst=172.16.241.164 |<TCP  sport=http dport=60713 seq=81 ack=20 flags=SA window=4225 |>>, <IP  frag=0 proto=tcp src=172.16.241.164 dst=10.0.89.36 |<TCP  sport=60713 dport=http seq=20 ack=82 flags=A window=2105 |>>, <IP  frag=0 proto=tcp src=10.0.89.36 dst=172.16.241.164 |<TCP  sport=http dport=60713 seq=82 ack=20 flags=A window=4225 |>>, <IP  frag=0 proto=tcp src=10.0.89.36 dst=172.16.241.164 |<TCP  sport=http dport=60713 seq=82 ack=20 flags=PA window=8192 |<HTTP  |<HTTPRequest  Method='GET' Path='/' Http_Version='HTTP/1.1' Host='www.xvideos.com' |>>>>, <IP  frag=0 proto=tcp src=172.16.241.164 dst=10.0.89.36 |<TCP  sport=60713 dport=http seq=20 ack=123 flags=A window=2105 |>>, <IP  frag=0 proto=tcp src=172.16.241.164 dst=10.0.89.36 |<TCP  sport=60713 dport=http seq=20 ack=123 flags=PA window=8192 |<HTTP  |<HTTPResponse  Http_Version='HTTP/1.1' Status_Code='200' Reason_Phrase='OK' |<Raw  load='<HTML><BODY><H1>Welcome to xvideos!</H1></BODY></HTML>' |>>>>>, <IP  frag=0 proto=tcp src=10.0.89.36 dst=172.16.241.164 |<TCP  sport=http dport=60713 seq=123 ack=93 flags=A window=4225 |>>, <IP  frag=0 proto=tcp src=10.0.89.36 dst=172.16.241.164 |<TCP  sport=http dport=60713 seq=123 ack=93 flags=FA window=4225 |>>, <IP  frag=0 proto=tcp src=172.16.241.164 dst=10.0.89.36 |<TCP  sport=60713 dport=http seq=93 ack=123 flags=A window=2105 |>>, <IP  frag=0 proto=tcp src=17 ...
#
# Generated 15 packets.
# Writing them to ../../data/MOE/pcap/MOE_Conversations_generated_3_5_turbo-instruct_conv.pcap ...
# Done!
