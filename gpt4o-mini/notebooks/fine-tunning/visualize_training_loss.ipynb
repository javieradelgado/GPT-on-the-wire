# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("TrainingLoss/ICMPv1.csv", sep="\t").set_index('Step')
# reverse the order of rows
df = df.iloc[::-1]
df
# Out:
#           Time  Training loss Validation loss Full validation loss
# Step
# 1     20:54:03         0.8672               -                    -
# 2     20:54:05         0.8632               -                    -
# 3     20:54:09         0.8788               -                    -
# 4     20:54:13         0.8421               -                    -
# 5     20:54:15         0.6119               -                    -
# ...        ...            ...             ...                  ...
# 276   21:05:12         0.0020               -                    -
# 277   21:05:14         0.0168               -                    -
# 278   21:05:16         0.2733               -                    -
# 279   21:05:20         0.0511               -                    -
# 280   21:05:22         0.0480          0.0514               0.0497
#
# [280 rows x 4 columns]

# %%
TL="Final Training Loss = " + str(df["Training loss"][280])

plt.figure(figsize=(10,5))
plt.title("GPT-3.5 turbo-Instruct Training Loss During ICMP Fine-tuning")
plt.plot(df['Training loss'].to_numpy(),label=TL)

plt.xlabel("Steps")
plt.ylabel("Loss")
plt.legend()
plt.savefig("visualizations/ICMP/35TurboInstruct_loss.png",dpi=300)
plt.show()
