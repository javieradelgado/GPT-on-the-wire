# %% [markdown]
# # Creación de conversaciones HTTP

# %% [markdown]
# ### Descripción:
# Con este código se va a intentar crear todos los pasos de una conversación HTTP, mediante IA generativa. Se pretende pasar una descripción de esta conversación al modelo y que este sea capaz de crear todos los pasos/paquetes necesarios para replicar una conversación con esas mismas especificaciones

# %%
import random
import re
import pickle
import os 
import openai
from openai import OpenAI
os.environ['OPENAI_API_KEY'] = ''
client = OpenAI()

from scapy.all import *
from scapy.utils import RawPcapReader, wrpcap
import scapy.all as scapy

from scapy.layers.inet import IP, TCP
from scapy.layers.http import *

openai.__version__
# Out:
# C:\Users\adayd\anaconda3\envs\PAC-GPT\Lib\site-packages\scapy\layers\ipsec.py:469: CryptographyDeprecationWarning: Blowfish has been deprecated
#   cipher=algorithms.Blowfish,
# C:\Users\adayd\anaconda3\envs\PAC-GPT\Lib\site-packages\scapy\layers\ipsec.py:483: CryptographyDeprecationWarning: CAST5 has been deprecated
#   cipher=algorithms.CAST5,
# '1.10.0'

# %% [markdown]
# ## Step 1: Generación de la descipción de una comunicación HTTP
# ---

# %% [markdown]
# <center><img src="https://notes.shichao.io/tcpv1/figure_13-1.png">
#
# <center> Esta imagen es genérica, se intentará crear tanto la parte de hanshake como la terminación de la conversación en una primera aproximación. El intercambio de información siguiendo el protocolo HTTP se hace en la parte intermedia de la conversación, post handshake.

# %%
system_message = "This is a IPv4 TCP-HTTP conversation summary:\n"
system_message += 'Source: IP="193.24.227.230", port=40301, Window: 4128 // Destination: IP="9.9.9.9", port=80, Window: 256// Others: Host="http://ip.webernetz.net/", Path="", Code=200,  Content_Type="(text/html)"\n\n'

system_message += "x,y = random.sample(range(1, 100), 2)\n"
system_message += 'pkt_1= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="S", seq=y, window=4128)\n'
system_message += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
system_message += 'y += len(pkt_1[TCP].payload)+1\n'
system_message += 'pkt_2= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="SA", seq=x, ack=y, window=256)\n'
system_message += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
system_message += 'x += len(pkt_2[TCP].payload)+1\n'
system_message += 'pkt_3= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="A", seq=y, ack=x, window=4128)\n\n'
system_message += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
system_message += 'y += len(pkt_3[TCP].payload)\n'

system_message += 'pkt_4= IP(src="193.24.227.230",  dst="9.9.9.9") / TCP(sport=40301, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="ip.webernetz.net", Path="/")\n'
system_message += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
system_message += 'y += len(pkt_4[TCP].payload)\n'
system_message += 'pkt_5= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="A", seq=x, ack=y, window=4128)\n\n'
system_message += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
system_message += 'x += len(pkt_5[TCP].payload)\n'
system_message += 'pkt_6= IP(src="9.9.9.9",  dst="193.24.227.230") / TCP(sport=80, dport=40301, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "200", Reason_Phrase= "OK", Content_Type="text/html") / "<HTML><BODY><H!>Hello World!</H1></BODY></HTML>"\n'
system_message += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
system_message += 'x += len(pkt_6[TCP].payload)\n'
system_message += 'pkt_7= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="A", seq=y, ack=x, window=4128)\n\n'
system_message += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
system_message += 'y += len(pkt_7[TCP].payload)\n'

system_message += 'pkt_8= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="FA", seq=y, ack=x, window=4128)\n'
system_message += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
system_message += 'y += len(pkt_8[TCP].payload)\n'
system_message += 'pkt_9= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="A", seq=x, ack=y, window=256)\n'
system_message += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
system_message += 'x += len(pkt_9[TCP].payload)\n'
system_message += 'pkt_10= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="FA", seq=x, ack=y, window=256)\n'
system_message += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
system_message += 'x += len(pkt_10[TCP].payload)\n'
system_message += 'pkt_11= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="A", seq=y, ack=x, window=4128)\n\n'
system_message += 'y += len(pkt_11[TCP].payload)\n'

system_message += "Variable names in the HTTP definition are extremely important, use the exact same word. For example, use Http_Version, not http_version, use Method, not method.\n\n"
system_message += "In the HTTP response, if the variable code != 200, don´t use the Content_Type variable\n"
system_message += "Use the same dport for HTTPRequest (dport=80) and sport for HTTPResponse (sport=80), as this means we are creating a HTTP conection and using another port like 22 might make it seem like SSH traffic\n\n"
system_message += 'Pay special attention to the sequence and ack numbers so they make sense for a TCP conversation. The must be continuous throgh the conversation. Here you have a little explanation of how they work:\n'
system_message += 'The Sequence Number (SEQ) marks the starting byte of each segment sent. It increments by the number of bytes in the payload of each outgoing segment, reflecting the continuous flow of data.\n'
system_message += 'The Acknowledgment Number (ACK) acknowledges the receipt of data. It corresponds to the next expected byte the receiver anticipates from the sender. As segments arrive at the receiver, the ACK number adjusts to reflect the highest contiguous sequence number received.\n'
system_message += 'So, SEQ numbers increase with outgoing data, while ACK numbers advance with incoming acknowledgments, ensuring synchronized data exchange in a TCP connection.\n\n'

system_message += "Take your time (few seconds) to generate the commands and compare your proposed solution with real HTTP functioning, if anything is different, change it in order to do as real HTTP\n\n"

# %%
query = "This is a IPv4 TCP-HTTP conversation summary:\n"
query += 'Source: IP="193.24.227.230", port=40301, Window: 4128 // Destination: IP="9.9.9.9", port=80, Window: 256// Others: Host="http://ip.webernetz.net/", Path="", Code=200,  Content_Type="(text/html)"\n\n'

query += "This is the python code to generate the TCP 3 way hanshake packets of the conversation, respectively:\n"
query += "x,y = random.sample(range(1, 100), 2)\n"
query += 'pkt_1= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="S", seq=y, window=4128)\n'
query += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query += 'y= y+len(pkt_1[TCP].payload)+1\n'
query += 'pkt_2= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="SA", seq=x, ack=y, window=256)\n'
query += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query += 'y= y+len(pkt_1[TCP].payload)+1\n'
query += 'pkt_3= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="SA", seq=y+len(pkt_1[TCP].payload), ack=x+len(pkt_2[TCP].payload)+1, window=4128)\n\n'
query += 'time.sleep(abs(random.gauss(0, 0.03)))\n'

query += "This part between the handshake and the teardown must be filled with bidirectional realistic HTTP traffic, here is an example of these packets:\n"
query += 'pkt_4= IP(src="193.24.227.230",  dst="9.9.9.9") / TCP(sport=40301, dport=80, flags="PA", seq=y, ack=x+1, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="ip.webernetz.net", Path="/")\n'
query += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query += 'pkt_5= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=53, flags="A", seq=x, ack=y+len(pkt_4[TCP].payload), window=4128)\n\n'
query += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query += 'pkt_6= IP(src="9.9.9.9",  dst="193.24.227.230") / TCP(sport=80, dport=40301, flags="PA", seq=x+1, ack=y+len(pkt_4[TCP].payload)+len(pkt_4[TCP].payload), window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "200", Reason_Phrase= "OK", Content_Type="text/html") / "<HTML><BODY><H!>Hello World!</H1></BODY></HTML>"\n'
query += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query += 'pkt_7= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=53, flags="A", seq=K, ack=L+1, window=4128)\n\n'
query += 'time.sleep(abs(random.gauss(0, 0.03)))\n'

query += 'pkt_8= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="FA", seq=K, ack=L+ len(pkt_5[TCP].payload) +1, window=4128)\n'
query += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query += 'pkt_9= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="A", seq=L, ack=K+1, window=256)\n'
query += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query += 'pkt_10= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="FA", seq=L, ack=K+1, window=256)\n'
query += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query += 'pkt_11= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=53, flags="A", seq=K, ack=L+1, window=4128)\n\n'

query += "Variable names in the HTTP definition are extremely important, use the exact same word. For example, use Http_Version, not http_version, use Method, not method.\n\n"
query += "Use the same dport for HTTPRequest (dport=80) and sport for HTTPResponse (sport=80), as this means we are creating a HTTP conection and using another port like 22 might make it seem like SSH traffic\n\n"

query += 'Substitute variables x, y with random numbers but they must be the same along the conversation\n'
query += 'Variables K and L are critical and must be continuous with seq and ack numbers before them\n'

query += 'Pay special attention to the sequence and ack numbers so they make sense for a TCP conversation. The must be continuous throgh the conversation. Here you have a little explanation of how they work:\n'
query += 'The Sequence Number (SEQ) marks the starting byte of each segment sent. It increments by the number of bytes in the payload of each outgoing segment, reflecting the continuous flow of data.In the HTTP packets this payload represents the length of the HTTP Request and HTTP Response, this is described in the variables len(pkt_4[TCP].payload) and len(pkt_5[TCP].payload). Maintain this part in the commands as it is. This is ESSENTIAL\n'
query += 'The Acknowledgment Number (ACK) acknowledges the receipt of data. It corresponds to the next expected byte the receiver anticipates from the sender. As segments arrive at the receiver, the ACK number adjusts to reflect the highest contiguous sequence number received.\n'
query += 'So, SEQ numbers increase with outgoing data, while ACK numbers advance with incoming acknowledgments, ensuring synchronized data exchange in a TCP connection.\n\n'

query += "Take your time (few seconds) to generate the commands and compare your proposed solution with real HTTP functioning, if anything is different, change it in order to do as real HTTP\n\n"

query += 'You must also take into account the size of the TCP payload (in Bytes) in order to calculate the next ACK and SEQ number. In the HTTP packets this payload represents the length of the HTTP Request and HTTP Response, this is described in the variables len(pkt_4[TCP].payload) and len(pkt_5[TCP].payload). Maintain this part in the commands. This is ESSENTIAL.\n\n'

# %% [markdown]
# ## Step 2: Carga de posibles conversaciones
# ---

# %%
with open("../../data/Conversations/HTTP/Conv_summaries_vfin.txt","r",encoding="utf8") as f:
    Conv_summaries = f.read().splitlines()
print("Number of conversation summaries: " + str(len(Conv_summaries)))
# Out:
# Number of conversation summaries: 65

# %% [markdown]
# ### 2.1 Carga de posibles conversaciones anteriores para concatenarlas

# %%
class response():
    "Stores name and place pairs"
    def __init__(self, name, place):
        self.prompt_summary = name
        self.completion = place

# %%
try:
    responses = pickle.load( open("../../data/Conversations/HTTP/pickle/HTTP_pairs_Aday.pkl", "rb" ))
except:
    responses = []
    
print("Number of previous responses: " + str(len(responses)))
# Out:
# Number of previous responses: 0

# %% [markdown]
# ## Step 3: Generación de comandos de paquetes conversaciones TCP-HTTP
# ---

# %%
summaries_per_request = 1 # por que normalmente solo querremos generar una conversación

# %%
i=0
for i in range(len(Conv_summaries)):
    
    print("...........................................")
    print( " GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter " +str(i+1) +")")
    

    ## Luego seleccionas aleatoriamente resumenes ya generados para pedirle que te saque el comando a partir del paquete
    summary = Conv_summaries[i]
    text_sum = ""
    
    
    query_content = "This is a conversation summary:\n"
    query_content += summary + "\n"
    text_sum += summary + "\n"
    query_content += "\nGenerate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.\n"

    #Query es el mensaje que le envias al modelo
    print(query_content)

    messages=[{"role": "system", "content": system_message},
        {"role": "user", "content": query_content}]
    
    #Esta es la petición que le mandas al modelo de IA
    completion = client.chat.completions.create(
        model="gpt-4o-mini", 
        messages=messages,
        max_tokens=2600,
        temperature=0.1)
    
    
    print("...Generated!")
    
    
    # Guardamos tanto el resumen de los paquetes que solicitamos y lo que devuelve el modelo para estos paquetes
    responses.append(response(text_sum, completion))
    
    
    codigo = responses[-1].completion.choices[0].message.content
    
    if codigo.startswith("```python"):
        codigo = codigo[len("```python"):].lstrip()  # Elimina ```python al inicio
    if codigo.endswith("```"):
        codigo = codigo[:-len("```")].rstrip()  # Elimina ``` al final
    
    exec(codigo)
        
    pkt_list = [pkt_1, pkt_2, pkt_3, pkt_4, pkt_5, pkt_6, pkt_7, pkt_8, pkt_9, pkt_10, pkt_11]
    
    
    
    # Guardamos los paquetes generados en un pcap
    with open("../../data/Conversations/HTTP/pcap/HTTP_generated_gpt_4omini.pcap", "ba+") as f:
        wrpcap(f, pkt_list, append=True)
        
    # Guardamos tanto la petición como la respuesta en un archivo
    pickle.dump(responses, open( "../../data/Conversations/HTTP/pickle/HTTP_pairs_Aday.pkl", "wb" ) )
    
    print("Number of completitions done: " + str(len(responses)))
# Out:
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 1)
# This is a conversation summary:
# Source: IP="192.168.1.10", port=1241, Window: 8192 // Destination: IP="192.168.1.20", port=80, Window: 1634 // Others: Host="http://ip.webernetz.net/", Path="", Code=200, Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 1
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 2)
# This is a conversation summary:
# Source: IP="58.29.214.109", port=1123, Window: 48392 // Destination: IP="204.79.197.200", port=80, Window: 24196 // Others: Host="http://www.pinterest.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 2
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 3)
# This is a conversation summary:
# Source: IP="50.62.160.105", port=5020, Window: 12345 // Destination: IP="104.244.42.129", port=80, Window: 6172 // Others: Host="http://www.twitter.com/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 3
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 4)
# This is a conversation summary:
# Source: IP="172.16.0.5", port=3581, Window: 4096 // Destination: IP="172.16.0.15", port=80, Window: 3593 // Others: Host="http://www.youtube.com/", Path="", Code=200, Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 4
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 5)
# This is a conversation summary:
# Source: IP="93.184.216.34", port=4430, Window: 15000 // Destination: IP="13.107.21.200", port=80, Window: 7500 // Others: Host="http://www.medium.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 5
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 6)
# This is a conversation summary:
# Source: IP="205.251.242.103", port=5021, Window: 23456 // Destination: IP="151.101.0.223", port=80, Window: 11728 // Others: Host="http://www.imgur.com/", Path="", Code=404, Reason_Phrase= "Not Found"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 6
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 7)
# This is a conversation summary:
# Source: IP="10.10.10.1", port=8239, Window: 512 // Destination: IP="10.10.10.2", port=80, Window: 3491 // Others: Host="http://www.facebook.com/", Path="", Code=200, Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 7
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 8)
# This is a conversation summary:
# Source: IP="203.0.113.76", port=3380, Window: 22500 // Destination: IP="104.215.148.63", port=80, Window: 11250 // Others: Host="http://www.quora.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 8
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 9)
# This is a conversation summary:
# Source: IP="192.229.233.33", port=5022, Window: 34567 // Destination: IP="192.0.73.2", port=80, Window: 17283 // Others: Host="http://www.wordpress.com/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 9
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 10)
# This is a conversation summary:
# Source: IP="192.168.0.100", port=8080, Window: 3768 // Destination: IP="192.168.0.101", port=80, Window: 6536 // Others: Host="http://www.twitter.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 10
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 11)
# This is a conversation summary:
# Source: IP="192.0.2.123", port=2211, Window: 48000 // Destination: IP="40.76.4.15", port=80, Window: 24000 // Others: Host="http://www.github.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 11
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 12)
# This is a conversation summary:
# Source: IP="69.63.176.13", port=5023, Window: 45678 // Destination: IP="185.60.216.35", port=80, Window: 22839 // Others: Host="http://www.faceboForbidden.com/", Path="", Code=404, Reason_Phrase= "Not Found"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 12
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 13)
# This is a conversation summary:
# Source: IP="172.31.255.254", port=2395, Window: 2048 // Destination: IP="172.31.255.253", port=80, Window: 4096 // Others: Host="http://www.instagram.com/", Path="",  Code=200, Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 13
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 14)
# This is a conversation summary:
# Source: IP="198.51.100.233", port=1199, Window: 30000 // Destination: IP="65.55.44.108", port=80, Window: 15000 // Others: Host="http://www.gitlab.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 14
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 15)
# This is a conversation summary:
# Source: IP="87.248.98.7", port=5024, Window: 56789 // Destination: IP="69.171.250.35", port=80, Window: 28394 // Others: Host="http://www.flickr.com/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 15
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 16)
# This is a conversation summary:
# Source: IP="10.0.0.50", port=4582, Window: 1684 // Destination: IP="10.0.0.51", port=80, Window: 8192 // Others: Host="http://www.amazon.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 16
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 17)
# This is a conversation summary:
# Source: IP="51.15.127.128", port=8081, Window: 45000 // Destination: IP="13.107.246.10", port=80, Window: 22500 // Others: Host="http://www.stackoverflow.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 17
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 18)
# This is a conversation summary:
# Source: IP="72.21.91.29", port=5025, Window: 13579 // Destination: IP="31.13.71.36", port=80, Window: 6789 // Others: Host="http://www.instagram.com/", Path="", Code=404, Reason_Phrase= "Not Found"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 18
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 19)
# This is a conversation summary:
# Source: IP="192.168.1.254", port=9358, Window: 256 // Destination: IP="192.168.1.253", port=80, Window: 512 // Others: Host="http://www.wikipedia.org/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 19
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 20)
# This is a conversation summary:
# Source: IP="64.233.160.255", port=5001, Window: 35000 // Destination: IP="204.79.197.212", port=80, Window: 17500 // Others: Host="http://www.google.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 20
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 21)
# This is a conversation summary:
# Source: IP="23.227.38.32", port=5026, Window: 24680 // Destination: IP="66.220.144.0", port=80, Window: 12340 // Others: Host="http://www.shopify.com/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 21
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 22)
# This is a conversation summary:
# Source: IP="172.16.0.254", port=3389, Window: 8192 // Destination: IP="172.16.0.253", port=80, Window: 4096 // Others: Host="http://www.reddit.com/", Path="", Code=200,   Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 22
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 23)
# This is a conversation summary:
# Source: IP="17.172.224.47", port=5002, Window: 40000 // Destination: IP="13.107.42.12", port=80, Window: 20000 // Others: Host="http://www.apple.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 23
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 24)
# This is a conversation summary:
# Source: IP="69.63.176.15", port=5027, Window: 9865 // Destination: IP="69.63.176.59", port=80, Window: 49382 // Others: Host="http://www.whatsapp.com/", Path="", Code=404, Reason_Phrase= "Not Found"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 24
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 25)
# This is a conversation summary:
# Source: IP="10.10.10.254", port=1831, Window: 1024 // Destination: IP="10.10.10.253", port=80, Window: 512 // Others: Host="http://www.yahoo.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 25
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 26)
# This is a conversation summary:
# Source: IP="23.253.58.227", port=5003, Window: 3000 // Destination: IP="104.215.148.63", port=80, Window: 16000 // Others: Host="http://www.rackspace.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 26
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 27)
# This is a conversation summary:
# Source: IP="34.213.106.51", port=5028, Window: 8654 // Destination: IP="31.13.85.36", port=80, Window: 43827 // Others: Host="http://www.messenger.com/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 27
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 28)
# This is a conversation summary:
# Source: IP="192.168.0.1", port=1348, Window: 6536 // Destination: IP="192.168.0.2", port=80, Window: 3268 // Others: Host="http://www.netflix.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 28
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 29)
# This is a conversation summary:
# Source: IP="72.14.207.99", port=5004, Window: 47000 // Destination: IP="40.113.200.201", port=80, Window: 23500 // Others: Host="http://www.blogspot.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 29
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 30)
# This is a conversation summary:
# Source: IP="52.95.245.18", port=5029, Window: 7543 // Destination: IP="157.240.1.35", port=80, Window: 38271 // Others: Host="http://www.oculus.com/", Path="", Code=404, Reason_Phrase= "Not Found"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 30
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 31)
# This is a conversation summary:
# Source: IP="172.31.0.1", port=3306, Window: 4096 // Destination: IP="172.31.0.2", port=80, Window: 2048 // Others: Host="http://www.linkedin.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 31
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 32)
# This is a conversation summary:
# Source: IP="87.250.250.242", port=5005, Window: 2000 // Destination: IP="13.77.161.179", port=80, Window: 14000 // Others: Host="http://www.yandex.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 32
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 33)
# This is a conversation summary:
# Source: IP="54.192.48.195", port=5030, Window: 6432 // Destination: IP="69.63.178.15", port=80, Window: 32716 // Others: Host="http://www.audible.com/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 33
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 34)
# This is a conversation summary:
# Source: IP="10.0.0.100", port=1813, Window: 8192 // Destination: IP="10.0.0.101", port=80, Window: 1684 // Others: Host="http://www.ebay.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 34
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 35)
# This is a conversation summary:
# Source: IP="99.84.224.58", port=5006, Window: 2600 // Destination: IP="40.112.72.205", port=80, Window: 13000 // Others: Host="http://www.amazon.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 35
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 36)
# This is a conversation summary:
# Source: IP="13.33.23.213", port=5031, Window: 5321 // Destination: IP="31.13.92.14", port=80, Window: 27160 // Others: Host="http://www.onavo.com/", Path="", Code=404, Reason_Phrase= "Not Found"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 36
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 37)
# This is a conversation summary:
# Source: IP="192.168.1.1", port=2394, Window: 512 // Destination: IP="192.168.1.2", port=80, Window: 256 // Others: Host="http://www.apple.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 37
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 38)
# This is a conversation summary:
# Source: IP="103.21.244.15", port=5007, Window: 3300 // Destination: IP="13.107.213.40", port=80, Window: 16500 // Others: Host="http://www.cloudflare.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 38
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 39)
# This is a conversation summary:
# Source: IP="99.86.58.21", port=5032, Window: 4310 // Destination: IP="157.240.7.35", port=80, Window: 21605 // Others: Host="http://www.portal.faceboForbidden.com/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 39
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 40)
# This is a conversation summary:
# Source: IP="172.16.0.1", port=2359, Window: 4096 // Destination: IP="172.16.0.2", port=80, Window: 8192 // Others: Host="http://www.microsoft.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 40
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 41)
# This is a conversation summary:
# Source: IP="13.224.29.28", port=5008, Window: 3000 // Destination: IP="104.40.211.35", port=80, Window: 18000 // Others: Host="http://www.akamai.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 41
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 42)
# This is a conversation summary:
# Source: IP="52.84.125.96", port=5033, Window: 3109 // Destination: IP="192.229.233.50", port=80, Window: 16054 // Others: Host="http://www.w3schools.com/", Path="", Code=404, Reason_Phrase= "Not Found"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 42
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 43)
# This is a conversation summary:
# Source: IP="10.10.10.10", port=2922, Window: 512 // Destination: IP="10.10.10.11", port=80, Window: 1024 // Others: Host="http://marca.es/", Path="", Code=200,  Reason_Phrase= "OK",
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 43
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 44)
# This is a conversation summary:
# Source: IP="151.101.1.140", port=5009, Window: 3000 // Destination: IP="40.76.4.15", port=80, Window: 15500 // Others: Host="http://www.fastly.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 44
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 45)
# This is a conversation summary:
# Source: IP="13.224.194.4", port=5034, Window: 21098 // Destination: IP="52.95.245.18", port=80, Window: 10549 // Others: Host="http://www.primevideo.com/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 45
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 46)
# This is a conversation summary:
# Source: IP="192.168.0.254", port=8080, Window: 3268 // Destination: IP="192.168.0.253", port=80, Window: 6556 // Others: Host="http://www.imgur.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 46
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 47)
# This is a conversation summary:
# Source: IP="199.232.37.140", port=5010, Window: 2900 // Destination: IP="13.107.246.10", port=80, Window: 14500 // Others: Host="http://www.maxcdn.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 47
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 48)
# This is a conversation summary:
# Source: IP="54.192.48.195", port=5035, Window: 1987 // Destination: IP="13.33.23.213", port=80, Window: 5493 // Others: Host="http://www.goodreads.com/", Path="", Code=404, Reason_Phrase= "Not Found"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 48
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 49)
# This is a conversation summary:
# Source: IP="172.31.255.1", port=2358, Window: 2048 // Destination: IP="172.31.255.2", port=80, Window: 4096 // Others: Host="http://www.pinterest.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 49
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 50)
# This is a conversation summary:
# Source: IP="185.199.108.153", port=5011, Window: 2000 // Destination: IP="104.215.148.63", port=80, Window: 13500 // Others: Host="http://www.pages.github.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 50
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 51)
# This is a conversation summary:
# Source: IP="99.86.58.21", port=5036, Window: 19876 // Destination: IP="52.84.125.96", port=80, Window: 9938 // Others: Host="http://www.amazonaws.com/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 51
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 52)
# This is a conversation summary:
# Source: IP="10.0.0.150", port=9492, Window: 1634 // Destination: IP="10.0.0.151", port=80, Window: 8192 // Others: Host="http://www.twitch.tv/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 52
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 53)
# This is a conversation summary:
# Source: IP="151.101.65.195", port=5012, Window: 2000 // Destination: IP="40.113.200.201", port=80, Window: 12500 // Others: Host="http://www.vimeo.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 53
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 54)
# This is a conversation summary:
# Source: IP="13.224.194.4", port=5037, Window: 28765 // Destination: IP="54.192.48.195", port=80, Window: 14382 // Others: Host="http://www.zappos.com/", Path="", Code=404, Reason_Phrase= "Not Found"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 54
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 55)
# This is a conversation summary:
# Source: IP="192.168.1.100", port=3292, Window: 256 // Destination: IP="192.168.1.101", port=80, Window: 512 // Others: Host="http://www.spotify.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 55
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 56)
# This is a conversation summary:
# Source: IP="192.229.162.112", port=5013, Window: 2000 // Destination: IP="13.77.161.179", port=80, Window: 11500 // Others: Host="http://www.edgecast.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 56
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 57)
# This is a conversation summary:
# Source: IP="52.95.245.18", port=5038, Window: 37654 // Destination: IP="99.86.58.21", port=80, Window: 18827 // Others: Host="http://www.twitch.tv/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 57
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 58)
# This is a conversation summary:
# Source: IP="172.16.0.100", port=3389, Window: 8192 // Destination: IP="172.16.0.101", port=80, Window: 4096 // Others: Host="http://www.nytimes.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 58
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 59)
# This is a conversation summary:
# Source: IP="198.185.159.144", port=5014, Window: 21000 // Destination: IP="40.112.72.205", port=80, Window: 10500 // Others: Host="http://www.squarespace.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 59
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 60)
# This is a conversation summary:
# Source: IP="13.33.23.213", port=5039, Window: 46543 // Destination: IP="13.224.194.4", port=80, Window: 23271 // Others: Host="http://www.imdb.com/", Path="", Code=404, Reason_Phrase= "Not Found"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 60
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 61)
# This is a conversation summary:
# Source: IP="10.10.10.100", port=3951, Window: 1024 // Destination: IP="10.10.10.101", port=80, Window: 512 // Others: Host="http://www.dropbox.com/", Path="", Code=200,  Reason_Phrase= "OK",
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 61
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 62)
# This is a conversation summary:
# Source: IP="23.235.33.217", port=5015, Window: 1000 // Destination: IP="13.107.213.40", port=80, Window: 9500 // Others: Host="http://www.inmotionhosting.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 62
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 63)
# This is a conversation summary:
# Source: IP="99.86.58.21", port=5040, Window: 5432 // Destination: IP="52.95.245.18", port=80, Window: 27716 // Others: Host="http://www.kindle.com/", Path="", Code=403, Reason_Phrase= "Forbidden"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 63
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 64)
# This is a conversation summary:
# Source: IP="192.168.0.10", port=4592, Window: 6553 // Destination: IP="192.168.0.11", port=80, Window: 3276 // Others: Host="http://www.bbc.co.uk/", Path="", Code=200,  Reason_Phrase= "OK"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 64
# ...........................................
#  GENERATING SCAPY COMMANDS FOR THE FOLLOWING CONVERSATIONS (iter 65)
# This is a conversation summary:
# Source: IP="104.16.41.2", port=5016, Window: 17000 // Destination: IP="104.40.211.35", port=80, Window: 8500 // Others: Host="http://www.bluehost.com/", Path="", Code=307, Reason_Phrase= "Temporary Redirect"
#
# Generate python code for creating the packets in the conversation with scapy framework.Don´t give back any comments, just bare code. PLEASE DONT start the resposnses wiht ```python This is a flagrant error and will make the code unexecutable. You have done this last step wrong plenty of times, take your time to generate the output withount ```python please.
#
# ...Generated!
# Number of completitions done: 65

# %%
print(responses[-1].completion.choices[0].message.content[9:-4])
# Out:
# from scapy.all import *
# import random
# import time
#
# x, y = random.sample(range(1, 100), 2)
#
# pkt_1 = IP(src="205.251.242.103", dst="151.101.0.223") / TCP(sport=5021, dport=80, flags="S", seq=y, window=23456)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_1[TCP].payload) + 1
#
# pkt_2 = IP(src="151.101.0.223", dst="205.251.242.103") / TCP(sport=80, dport=5021, flags="SA", seq=x, ack=y, window=11728)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_2[TCP].payload) + 1
#
# pkt_3 = IP(src="205.251.242.103", dst="151.101.0.223") / TCP(sport=5021, dport=80, flags="A", seq=y, ack=x, window=23456)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_3[TCP].payload)
#
# pkt_4 = IP(src="205.251.242.103", dst="151.101.0.223") / TCP(sport=5021, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method="GET", Http_Version="HTTP/1.1", Host="www.imgur.com", Path="/")
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_4[TCP].payload)
#
# pkt_5 = IP(src="151.101.0.223", dst="205.251.242.103") / TCP(sport=80, dport=5021, flags="A", seq=x, ack=y, window=11728)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_5[TCP].payload)
#
# pkt_6 = IP(src="151.101.0.223", dst="205.251.242.103") / TCP(sport=80, dport=5021, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version="HTTP/1.1", Status_Code="404", Reason_Phrase="Not Found") / "<HTML><BODY><H1>404 Not Found</H1></BODY></HTML>"
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_6[TCP].payload)
#
# pkt_7 = IP(src="205.251.242.103", dst="151.101.0.223") / TCP(sport=5021, dport=80, flags="A", seq=y, ack=x, window=23456)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_7[TCP].payload)
#
# pkt_8 = IP(src="205.251.242.103", dst="151.101.0.223") / TCP(sport=5021, dport=80, flags="FA", seq=y, ack=x, window=23456)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_8[TCP].payload)
#
# pkt_9 = IP(src="151.101.0.223", dst="205.251.242.103") / TCP(sport=80, dport=5021, flags="A", seq=x, ack=y, window=11728)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_9[TCP].payload)
#
# pkt_10 = IP(src="151.101.0.223", dst="205.251.242.103") / TCP(sport=80, dport=5021, flags="FA", seq=x, ack=y, window=11728)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_10[TCP].payload)
#
# pkt_11 = IP(src="205.251.242.103", dst="151.101.0.223") / TCP(sport=5021, dport=80, flags="A", seq=y, ack=x, window=23456)

# %% [markdown]
# responses[-1].completion.choices[0].message.content[9:-4]## Step 4: Estudio de los resultados
# ---

# %%
# Este es el resumen de lo que está en el struct de responses para la última petición
print(responses[-1].prompt_summary)
print(responses[-1].completion.choices[0].text)
# Out:
# Source: IP="192.168.0.100", port=8080, Window: 3768 // Destination: IP="192.168.0.101", port=80, Window: 6536 // Others: Host="http://www.twitter.com/", Path="", Code=200,  Reason_Phrase= "OK"
#
#
# x,y = random.sample(range(1, 100), 2)
# pkt_1= IP(src="192.168.0.100", dst="192.168.0.101")/TCP(sport=8080, dport=80, flags="S", seq=y, window=3768)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_1[TCP].payload)+1
# pkt_2= IP(src="192.168.0.101", dst="192.168.0.100")/TCP(sport=80, dport=8080, flags="SA", seq=x, ack=y, window=6536)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_2[TCP].payload)+1
# pkt_3= IP(src="192.168.0.100", dst="192.168.0.101")/TCP(sport=8080, dport=80, flags="A", seq=y, ack=x, window=3768)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_3[TCP].payload)
# This part between the handshake and the teardown must be filled with bidirectional realistic HTTP traffic, here is an example of these packets:
# pkt_4= IP(src="192.168.0.100",  dst="192.168.0.101") / TCP(sport=8080, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="www.twitter.com", Path="/")
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_4[TCP].payload)
# pkt_5= IP(src="192.168.0.101", dst="192.168.0.100")/TCP(sport=80, dport=8080, flags="A", seq=x, ack=y, window=6536)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_5[TCP].payload)
# pkt_6= IP(src="192.168.0.101",  dst="192.168.0.100") / TCP(sport=80, dport=8080, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "200", Reason_Phrase= "OK") / "<HTML><BODY><H1>Welcome to Twitter!</H1></BODY></HTML>"
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_6[TCP].payload)
# pkt_7= IP(src="192.168.0.100", dst="192.168.0.101")/TCP(sport=8080, dport=80, flags="A", seq=y, ack=x, window=3768)
#
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_7[TCP].payload)
# This is the python code to generate the TCP teardown packets of the conversation, respectively:
# pkt_8= IP(src="192.168.0.100", dst="192.168.0.101")/TCP(sport=8080, dport=80, flags="FA", seq=y, ack=x, window=3768)
# time.sleep(abs(random.gauss(0, 0.03)))
# y += len(pkt_8[TCP].payload)
# pkt_9= IP(src="192.168.0.101", dst="192.168.0.100")/TCP(sport=80, dport=8080, flags="A", seq=x, ack=y, window=6536)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_9[TCP].payload)
# pkt_10= IP(src="192.168.0.101", dst="192.168.0.100")/TCP(sport=80, dport=8080, flags="FA", seq=x, ack=y, window=6536)
# time.sleep(abs(random.gauss(0, 0.03)))
# x += len(pkt_10[TCP].payload)
# pkt_11= IP(src="192.168.0.100", dst="192.168.0.101")/TCP(sport=8080, dport=80, flags="A", seq=y, ack=x, window=3768)
#
# y += len(pkt_11[TCP].payload)

# %% [markdown]
# ### 4.1 Generación de paquetes

# %%
# Ejecutamos los comandos que devuelve el modelo para generar los paquetes
exec(responses[-1].completion.choices[0].text)
pkt_list = [pkt_1, pkt_2, pkt_3, pkt_4, pkt_5, pkt_6, pkt_7, pkt_8, pkt_9, pkt_10, pkt_11]
print(pkt_list)
# Out:
# [<IP  frag=0 proto=tcp src=10.0.0.200 dst=10.0.0.201 |<TCP  sport=9352 dport=http seq=99 flags=S window=8192 |>>, <IP  frag=0 proto=tcp src=10.0.0.201 dst=10.0.0.200 |<TCP  sport=http dport=9352 seq=6 ack=100 flags=SA window=1384 |>>, <IP  frag=0 proto=tcp src=10.0.0.200 dst=10.0.0.201 |<TCP  sport=9352 dport=http seq=100 ack=7 flags=A window=8192 |>>, <IP  frag=0 proto=tcp src=10.0.0.200 dst=10.0.0.201 |<TCP  sport=9352 dport=http seq=100 ack=7 flags=PA window=8192 |<HTTP  |<HTTPRequest  Method='GET' Path='/' Http_Version='HTTP/1.1' Host='ip.webernetz.net' |>>>>, <IP  frag=0 proto=tcp src=10.0.0.201 dst=10.0.0.200 |<TCP  sport=http dport=9352 seq=7 ack=142 flags=A window=1384 |>>, <IP  frag=0 proto=tcp src=10.0.0.201 dst=10.0.0.200 |<TCP  sport=http dport=9352 seq=7 ack=142 flags=PA window=8192 |<HTTP  |<HTTPResponse  Http_Version='HTTP/1.1' Status_Code='200' Reason_Phrase='OK' Content_Type='text/html' |<Raw  load='<HTML><BODY><H1>Hello World!</H1></BODY></HTML>' |>>>>>, <IP  frag=0 proto=tcp src=10.0.0.200 dst=10.0.0.201 |<TCP  sport=9352 dport=http seq=142 ack=98 flags=A window=8192 |>>, <IP  frag=0 proto=tcp src=10.0.0.200 dst=10.0.0.201 |<TCP  sport=9352 dport=http seq=142 ack=98 flags=FA window=8192 |>>, <IP  frag=0 proto=tcp src=10.0.0.201 dst=10.0.0.200 |<TCP  sport=http dport=9352 seq=98 ack=142 flags=A window=1384 |>>, <IP  frag=0 proto=tcp src=10.0.0.201 dst=10.0.0.200 |<TCP  sport=http dport=9352 seq=98 ack=142 flags=FA window=1384 |>>, <IP  frag=0 proto=tcp src=10.0.0.200 dst=10.0.0.201 |<TCP  sport=9352 dport=http seq=142 ack=98 flags=A window=8192 |>>]

# %%
#Enviarlos para probar si se envian correctamente
send(pkt_list)
# Out:
# Sent 11 packets.

# %% [markdown]
# ## Step 5: Introducción en un pcap
# ---

# %%
# Guardamos los paquetes generados en un pcap
with open("../../data/Conversations/HTTP/pcap/HTTP_Conv2_generated_3_5_turbo-instruct_conv_ALL.pcap", "ba+") as f:
    wrpcap(f, pkt_list, append=True)

# %%
query_p = "x,y = random.sample(range(1, 100), 2)\n"
query_p += 'print(y)\n'
query_p += 'pkt_1= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="S", seq=y, window=4128)\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'y += len(pkt_1[TCP].payload)+1\n'
query_p += 'pkt_2= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="SA", seq=x, ack=y, window=256)\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'x += len(pkt_2[TCP].payload)+1\n'
query_p += 'pkt_3= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="A", seq=y, ack=x, window=4128)\n\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'y += len(pkt_3[TCP].payload)\n'

query_p += 'pkt_4= IP(src="193.24.227.230",  dst="9.9.9.9") / TCP(sport=40301, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="ip.webernetz.net", Path="/")\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'y += len(pkt_4[TCP].payload)\n'
query_p += 'print(y)\n'
query_p += 'pkt_5= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="A", seq=x, ack=y, window=4128)\n\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'x += len(pkt_5[TCP].payload)\n'
query_p += 'pkt_6= IP(src="9.9.9.9",  dst="193.24.227.230") / TCP(sport=80, dport=40301, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "200", Reason_Phrase= "OK", Content_Type="text/html") / "<HTML><BODY><H!>Hello World!</H1></BODY></HTML>"\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'x += len(pkt_6[TCP].payload)\n'
query_p += 'pkt_7= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="A", seq=y, ack=x, window=4128)\n\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'y += len(pkt_7[TCP].payload)\n'

query_p += 'pkt_8= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="FA", seq=y, ack=x, window=4128)\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'y += len(pkt_8[TCP].payload)\n'
query_p += 'pkt_9= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="A", seq=x, ack=y, window=256)\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'x += len(pkt_9[TCP].payload)\n'
query_p += 'pkt_10= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="FA", seq=x, ack=y, window=256)\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'x += len(pkt_10[TCP].payload)\n'
query_p += 'pkt_11= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="A", seq=y, ack=x, window=4128)\n\n'
query_p += 'y += len(pkt_11[TCP].payload)\n'

exec(query_p)

# %%
query_p = "x,y = random.sample(range(1, 100), 2)\n"
query_p += 'print(y)\n'
query_p += 'pkt_1= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="S", seq=y, window=4128)\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'y += len(pkt_1[TCP].payload)+1\n'
query_p += 'pkt_2= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="SA", seq=x, ack=y, window=256)\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'x += len(pkt_2[TCP].payload)+1\n'
query_p += 'pkt_3= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="A", seq=y, ack=x, window=4128)\n\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'y += len(pkt_3[TCP].payload)\n'

query_p += 'pkt_4= IP(src="193.24.227.230",  dst="9.9.9.9") / TCP(sport=40301, dport=80, flags="PA", seq=y, ack=x, window=8192) / HTTP() / HTTPRequest(Method ="GET", Http_Version="HTTP/1.1", Host="ip.webernetz.net", Path="/")\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'y += len(pkt_4[TCP].payload)\n'
query_p += 'print(y)\n'
query_p += 'pkt_5= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="A", seq=x, ack=y, window=4128)\n\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'x += len(pkt_5[TCP].payload)\n'
query_p += 'pkt_6= IP(src="9.9.9.9",  dst="193.24.227.230") / TCP(sport=80, dport=40301, flags="PA", seq=x, ack=y, window=8192) / HTTP() / HTTPResponse(Http_Version= "HTTP/1.1", Status_Code= "200", Reason_Phrase= "OK", Content_Type="text/html") / "<HTML><BODY><H!>Hello World!</H1></BODY></HTML>"\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'x += len(pkt_6[TCP].payload)\n'
query_p += 'pkt_7= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="A", seq=y, ack=x, window=4128)\n\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'y += len(pkt_7[TCP].payload)\n'

query_p += 'pkt_8= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="FA", seq=x, ack=y, window=256)\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'x += len(pkt_8[TCP].payload)\n'
query_p += 'pkt_9= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="A", seq=y, ack=x, window=4128)\n\n'
query_p += 'y += len(pkt_9[TCP].payload)\n'
query_p += 'pkt_10= IP(src="193.24.227.230", dst="9.9.9.9")/TCP(sport=40301, dport=80, flags="FA", seq=y, ack=x, window=4128)\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'y += len(pkt_10[TCP].payload)\n'
query_p += 'pkt_11= IP(src="9.9.9.9", dst="193.24.227.230")/TCP(sport=80, dport=40301, flags="A", seq=x, ack=y, window=256)\n'
query_p += 'time.sleep(abs(random.gauss(0, 0.03)))\n'
query_p += 'x += len(pkt_11[TCP].payload)\n'

exec(query_p)
# Out:
# 38
# 81

# %%
# Guardamos los paquetes generados en un pcap
with open("../../data/Conversations/HTTP/pcap/HTTP_Conv2_generated_3_5_turbo-instruct_conv_ALL.pcap", "ba+") as f:
    wrpcap(f, [pkt_1, pkt_2, pkt_3, pkt_4, pkt_5, pkt_6, pkt_7, pkt_8, pkt_9, pkt_10, pkt_11], append=True)

# %%
len(pkt_4[TCP].payload)
# Out:
# 42
